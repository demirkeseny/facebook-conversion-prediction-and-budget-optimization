# %% [markdown]
# # Generating Test Data

# %%
# Packages we need:
import pandas as pd
import numpy as np
import re
from datetime import datetime
from itertools import product
from datetime import date, timedelta
import calendar

# %%
from IPython.display import display
pd.options.display.max_columns = None
pd.options.display.max_rows = 500

# %% [markdown]
# # Getting the Input

# %% [markdown]
# There are some input data that we need to generate Excel file.

# %%
date1 = input("Please enter the first day of the prediction in a form of yyyy-mm-dd:")
# Out:
# Please enter the first day of the prediction in a form of yyyy-mm-dd:2019-08-01

# %%
date1 = datetime.strptime(date1, '%Y-%m-%d').date()

# %%
date2 = input("Please enter the last day of the prediction in a form of yyyy-mm-dd:")
# Out:
# Please enter the last day of the prediction in a form of yyyy-mm-dd:2019-08-31

# %%
date2 = datetime.strptime(date2, '%Y-%m-%d').date()

# %%
print("The predictions will run from {} until {}!".format(date1,date2))
# Out:
# The predictions will run from 2019-08-01 until 2019-08-31!

# %%
# budget_m = int(input("Please enter the monthly budget:"))

# %%
# budget_d = int(input("Please enter the daily budget:"))

# %% [markdown]
# ## Preparing the Data

# %% [markdown]
# The steps followed here are copied from the initial modelling notebook.

# %%
# Uploading the raw data from S3
import boto3
from sagemaker import get_execution_role

role = get_execution_role()
bucket='facebookconversionrates/fb_raw_data'
data_key = 'fbadset.xlsx'
data_location = 's3://{}/{}'.format(bucket, data_key)

df = pd.read_excel(data_location,
                   sheet_name=['sheet1', 'sheet2','sheet3','sheet4','sheet5','sheet6','sheet7','sheet8','sheet9','sheet10'], 
                   skiprows=None)

# %%
#convert dict to df to concat all sheets
dfs = []
for dfname in df.keys():
    temp_df = df[dfname]
    temp_df['Session'] = dfname
    dfs.append(temp_df)
    
df = pd.concat(dfs)

# %%
df.columns
# Out:
# Index(['Ad Account ID', 'Ad Account Name', 'Reporting starts',
#        'Reporting ends', 'Ad set name', 'Age', 'Ad set delivery', 'Bid',
#        'Bid Type', 'Ad set budget', 'Ad set budget type',
#        'Last significant edit', 'Results', 'Result indicator', 'Reach',
#        'Impressions', 'Cost per results', 'Amount spent (USD)', 'Ends',
#        'Starts', 'Link clicks', 'Website purchases', 'Leads (form)',
#        'Campaign name', 'Campaign ID', 'Lead - Page Contains thank-you',
#        'Lead Submission', 'Ad set ID', 'Landing page views', 'Session'],
#       dtype='object')

# %%
df.shape
# Out:
# (105971, 30)

# %%
df = df.sort_values(by='Reporting starts',ascending=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105971 entries, 7797 to 17744
# Data columns (total 30 columns):
# Ad Account ID                     105971 non-null int64
# Ad Account Name                   105971 non-null object
# Reporting starts                  105971 non-null datetime64[ns]
# Reporting ends                    105971 non-null datetime64[ns]
# Ad set name                       105971 non-null object
# Age                               105971 non-null object
# Ad set delivery                   105971 non-null object
# Bid                               105971 non-null int64
# Bid Type                          105971 non-null object
# Ad set budget                     105971 non-null float64
# Ad set budget type                105971 non-null object
# Last significant edit             105971 non-null object
# Results                           48315 non-null float64
# Result indicator                  48315 non-null object
# Reach                             105971 non-null int64
# Impressions                       105971 non-null int64
# Cost per results                  48301 non-null float64
# Amount spent (USD)                105971 non-null float64
# Ends                              105971 non-null object
# Starts                            105971 non-null object
# Link clicks                       94847 non-null float64
# Website purchases                 23 non-null float64
# Leads (form)                      8246 non-null float64
# Campaign name                     105971 non-null object
# Campaign ID                       105971 non-null int64
# Lead - Page Contains thank-you    29793 non-null float64
# Lead Submission                   15976 non-null float64
# Ad set ID                         105971 non-null int64
# Landing page views                84412 non-null float64
# Session                           105971 non-null object
# dtypes: datetime64[ns](2), float64(10), int64(6), object(12)
# memory usage: 25.1+ MB

# %%
#remove space and concat _column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('_-_', '_')

# %%
max(df['reporting_starts'])
# Out:
# Timestamp('2019-09-03 00:00:00')

# %%
min(df['reporting_starts'])
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df.drop_duplicates(keep=False,inplace=True)

# %%
df['ends'] = df['ends'].replace('Sürekli', 'Ongoing')

# %%
fb=df.copy()

# %%
fb['day_of_week']=fb['reporting_starts'].dt.dayofweek
days = {0:'Mon',1:'Tues',2:'Weds',3:'Thurs',4:'Fri',5:'Sat',6:'Sun'}
fb['day_of_week'] = fb['day_of_week'].apply(lambda x: days[x])

# %%
fb['year'],fb['month'],fb['week_num'] = fb['reporting_starts'].dt.year, fb['reporting_starts'].dt.month, fb['reporting_starts'].dt.week

# %%
#return_inverse : bool, optional
#If True, also return the indices of the unique array 
#(for the specified axis, if provided) that can be used to reconstruct ar.
def unique_val_count(a):
    unique, inverse = np.unique(a, return_inverse=True)
    count = np.zeros(len(unique), np.int)
    np.add.at(count, inverse, 1)
    return np.vstack((unique, count)).T

# %%
fb['campaign_name']=fb.campaign_name.str.replace('Facebook','').str.strip().str.replace(' ','')

# %%
fb['campaign_name']=fb['campaign_name'].str.replace(' ',
'').str.strip().apply(lambda x : x[1:] if x.startswith("-") else x)

# %%
fb['location'] = fb.campaign_name.str.split('-').str[0]
fb['topic'] = fb.campaign_name.str.split('-').str[1]
fb['type'] = fb.campaign_name.str.split('-').str[2]

# %%
fb['target'] = fb.ad_set_name.str.split('-').str[1]
fb['target_sub'] = fb.ad_set_name.str.split('-').str[2]
fb['version']=fb.ad_set_name.str.extract('-([^-]*)$')
#fb['version']=fb.ad_set_name.str.split('(\d+)').astype(int)

# %%
fb['target']=fb['target'].str.replace("AEC|CRE|Cloud|Event:Webinar|GEN|INS|MF|MSP|PS|RRE|TH",'').str.replace('-',"")
fb['target']=fb['target'].str.replace("AU|BoostedPost|CA|DE|EMEA|ES|FR|IT|MX|PL|SE|UK|US|ZA",'').str.replace('-',"")
fb['target']=fb['target'].str.replace("AU|BoostedPost|CA|DE|EMEA|ES|FR|IT|MX|PL|SE|UK|US|ZA|LAL|Latin America",'').str.replace('-',"")

# %%
fb['target_grouped'] = fb['target'].astype(str) + fb['target_sub'].astype(str)

# %%
unique_val_count(fb.target_grouped.astype(str)).tolist()
# Out:
# [['    All Lists ', 558],
#  ['    Brokers LAL ', 113],
#  ['    PS ', 104],
#  ['    Submitted Lead Form LAL ', 148],
#  ['    Website Remarketing ', 132],
#  ['   2% ', 230],
#  ['   Agents & Brokers ', 1625],
#  ['   All Lists ', 15856],
#  ['   All Lists  LAL ', 181],
#  ['   All Remarketing ', 116],
#  ['   Architects ', 1639],
#  ['   Awareness', 232],
#  ['   Awareness ', 1832],
#  ['   B2B TH + Online Advertisiing ', 80],
#  ['   B2B TH + Online Advertising ', 360],
#  ['   Brokers ', 223],
#  ['   Camera Sale LAL ', 110],
#  ['   Camera Sales & Buy Site LAL ', 605],
#  ['   Case Study ', 51],
#  ['   Claims Adjusters Job Titles ', 48],
#  ['   Construction ', 1722],
#  ['   Construction Webinar Event ', 12],
#  ['   DE/ROW ', 689],
#  ['   DQ Cost ', 356],
#  ['   DQ Cost Remarketing & LAL ', 16],
#  ['   DQ Cost Remarketing LAL ', 4],
#  ['   DQ Remarketing & LAL ', 20],
#  ['   David Troyer ', 268],
#  ['   December Sale ', 340],
#  ['   EBook ', 108],
#  ['   ENGL ', 1017],
#  ['   ENT Photography Entrepreneur ', 708],
#  ['   Engineers ', 374],
#  ['   Evergreen ', 9163],
#  ['   Feb Promo ', 2928],
#  ['   Flash Sale ', 48],
#  ['   Google Street View Photographers ', 387],
#  ['   Honquet Webinar Remarketing LAL ', 52],
#  ['   Hotel ', 450],
#  ['   Infographic ', 606],
#  ['   Insurance Company Employers ', 120],
#  ['   Interest Audience ', 1015],
#  ['   Interest Audience Real Estate ', 52],
#  ['   Interest Audience Real Estate Agents ', 516],
#  ['   Job Titles Claims, Adjusters ', 268],
#  ['   LAL ', 673],
#  ['   Leads LAL ', 341],
#  ['   Limited Time Offer ', 137],
#  ['   Limited Time Offer Website Remarketing ', 75],
#  ['   MQL ', 3505],
#  ['   MQL & SQL ', 1179],
#  ['   MultiFamily Property Management', 198],
#  ['   Opened Lead Form ', 604],
#  ['   Opened Lead Form LAL ', 819],
#  ['   Opened Lead Forms ', 540],
#  ['   Opened Lead Forms LAL ', 820],
#  ['   Opened Lead Forms LAL  ', 315],
#  ['   Opening Doors to New Opportunities', 230],
#  ['   Page Visitor Remarketing', 280],
#  ['   Page Visitor Remarketing ', 620],
#  ['   People Who Like MP Page ', 160],
#  ['   Photographers ', 404],
#  ['   Pro2 Lite Remarketing ', 32],
#  ['   REMAX Agents ', 40],
#  ['   ROW ', 248],
#  ['   RRE ', 32],
#  ['   Re', 444],
#  ['   Remarketing ', 352],
#  ['   Remax Agents ', 2568],
#  ['   Restoration Interests ', 472],
#  ['   Retargeting ', 287],
#  ['   Retargeting Website ', 390],
#  ['   SDR ', 210],
#  ['   SQL ', 1625],
#  ['   SQL 2', 528],
#  ['   SQL LAL ', 257],
#  ['   SeLoger Webinar Remarketing ', 96],
#  ['   Submitted Lead Form ', 3130],
#  ['   Submitted Lead Form  ', 52],
#  ['   Submitted Lead Form & LAL ', 492],
#  ['   Thriving 3D Business', 140],
#  ['   Vacation Rentals ', 256],
#  ['   Video & Website Remarketing ', 521],
#  ['   Video Remarketing ', 1589],
#  ['   Video Remarketing  & LAL ', 957],
#  ['   Video Remarketing  LAL & Website Remarketing', 975],
#  ['   Video Remarketing & LAL ', 1613],
#  ['   Webinar ', 177],
#  ['   Webinar Remarketing ', 709],
#  ['   Webinar Remarketing LAL ', 194],
#  ['   Website Remarketing ', 8595],
#  ['   Website Remarketing & LAL ', 1052],
#  ['   Website Remarketing LAL ', 899],
#  ['   Xactware 7.18', 240],
#  ['  3.0  Adventure, Extreme Sports Photography ', 44],
#  ['  3.0  Camera Brand Interests', 141],
#  ['  3.0  DQ & Lookalike ', 856],
#  ['  3.0  ETA + Camera Brand ', 855],
#  ['  3.0  Magazine Interests ', 44],
#  ['  Architects  LAL', 98],
#  ['  Buyer 2%  5% ', 56],
#  ['  Camera Sales  LAL', 153],
#  ['  Camera Sales  LAL ', 575],
#  ['  Evergreen ', 32],
#  ['  Facebook Page Engagement ', 354],
#  ['  MQL  LAL', 582],
#  ['  MQL  LAL ', 1600],
#  ['  REMAX Agents  LAL', 349],
#  ['  REMAX Agents  LAL ', 476],
#  ['  Remax Agents  LAL', 157],
#  ['  Site Retargeting  LAL', 201],
#  ['  Website  LAL', 36],
#  ['  Website Retargeting  LAL', 53],
#  [' 3D Reality Capture for Architectsnan', 28],
#  [' Accurate, Competitive Estimation for Construction Prosnan', 28],
#  [' All Lists  10', 115],
#  [' All Segments  Live Meetup ', 90],
#  [' Camera Sale  PS ', 15],
#  [' Caribbean Islands  RRE ', 1475],
#  [' Carribean Islands  RRE ', 28],
#  [' Clould 3.0  Website Remarketing & LAL ', 748],
#  [' ENGL  RRE ', 256],
#  [' ENT  Self Employed ', 594],
#  [' ENT  Self Employed / Drivers', 858],
#  [' ENT  Self Employed / Drivers ', 2608],
#  [' ENT/  Website Remarketing ', 1578],
#  [' Facebook Page Engagement  LAL', 163],
#  [' June 2019nan', 35],
#  [' Listing Presentation Panel Discussionnan', 56],
#  [' MQL & SQL  PS ', 238],
#  [' REMAX Agents & Brokers  LAL', 769],
#  [' REMAX Agents & Brokers  LAL ', 400],
#  [' Retargeting Website  LAL', 652],
#  [' Retargeting Website  LAL ', 1284],
#  [' SQL  10', 116],
#  [' SQL  LAL', 216],
#  [' SQL  LAL ', 432],
#  [' SQL  RRE ', 204],
#  [' SQL & MQL  RRE ', 152],
#  [' SQL 1025 ', 216],
#  [' Scan Leads  Awareness ', 104],
#  [' Website Retargeting  LAL', 183],
#  ['nannan', 114]]

# %%
fb.columns
# Out:
# Index(['ad_account_id', 'ad_account_name', 'reporting_starts',
#        'reporting_ends', 'ad_set_name', 'age', 'ad_set_delivery', 'bid',
#        'bid_type', 'ad_set_budget', 'ad_set_budget_type',
#        'last_significant_edit', 'results', 'result_indicator', 'reach',
#        'impressions', 'cost_per_results', 'amount_spent_(usd)', 'ends',
#        'starts', 'link_clicks', 'website_purchases', 'leads_(form)',
#        'campaign_name', 'campaign_id', 'lead_page_contains_thank-you',
#        'lead_submission', 'ad_set_id', 'landing_page_views', 'session',
#        'day_of_week', 'year', 'month', 'week_num', 'location', 'topic', 'type',
#        'target', 'target_sub', 'version', 'target_grouped'],
#       dtype='object')

# %%
fb['target_grouped'].replace(regex=True, inplace=True, to_replace=r'[^A-Za-z0-9]+',
value='')

# %%
fb.target_grouped=fb.target_grouped.str.strip().str.lower().str.replace(' ', '')

# %%
fb['target_grouped']=fb.target_grouped.str.replace('openedleadformslal','openedleadformlal')

# %%
fb['target_grouped']=fb.target_grouped.str.replace('MQLSQLPS','MQLSQL')

# %%
fb[['target_grouped']].head()
# Out:
#      target_grouped
# 7797      evergreen
# 7786      evergreen
# 7776      evergreen
# 7777      evergreen
# 7778      evergreen

# %%
fb['topic']=fb.topic.str.replace('Clould3.0','Cloud3.0')
fb['topic']=fb.topic.str.replace('CarribeanIslands','CaribbeanIslands')
fb['topic']=fb.topic.str.replace('AECArchitects','AEC')
fb['topic']=fb.topic.str.replace('CAWebsiteRetargeting','RetargetingWebsite')
fb['topic']=fb.topic.str.replace('CAWebsiteRetargeting','RetargetingWebsite')
fb['topic']=fb.topic.str.replace('WebsiteRetargeting','RetargetingWebsite')
fb['target']=fb.target.str.replace('Re','Re-Engagement')
fb['target']=fb.target.str.replace('&','')

# %%
age=['18-24', '25-34', '35-44', '45-54', '55-64', '65+']

# %%
fb=fb.query('age in @age')

# %%
#fill all blanks with novalue if the column dtype is object
fb = fb.apply(lambda x: x.fillna(0.0) if x.dtype.kind in 'biufc' else x.fillna('novalue'))

# %%
fb=fb.fillna(0.0)      #if the blanks are nan will need this line first

# %%
fb.columns
# Out:
# Index(['ad_account_id', 'ad_account_name', 'reporting_starts',
#        'reporting_ends', 'ad_set_name', 'age', 'ad_set_delivery', 'bid',
#        'bid_type', 'ad_set_budget', 'ad_set_budget_type',
#        'last_significant_edit', 'results', 'result_indicator', 'reach',
#        'impressions', 'cost_per_results', 'amount_spent_(usd)', 'ends',
#        'starts', 'link_clicks', 'website_purchases', 'leads_(form)',
#        'campaign_name', 'campaign_id', 'lead_page_contains_thank-you',
#        'lead_submission', 'ad_set_id', 'landing_page_views', 'session',
#        'day_of_week', 'year', 'month', 'week_num', 'location', 'topic', 'type',
#        'target', 'target_sub', 'version', 'target_grouped'],
#       dtype='object')

# %%
fb[(fb['location']=='US')&(fb['year']==2019) &(fb['topic']=='RRE')
   ].groupby(['campaign_name','ad_set_name','target_grouped']).size()
# Out:
# campaign_name           ad_set_name                                            target_grouped
# US-RRE-LeadSubmissions  US - RRE - Agents & Brokers - LAL - 10.17              agentsbrokers             128
#                         US - RRE - Camera Sale LAL - Evergreen - 4.24          camerasalelal             108
#                         US - RRE - Evergreen - Agents & Brokers - LAL - 4.10   evergreen                 256
#                         US - RRE - Evergreen - Agents & Brokers - LAL - 4.19   evergreen                 128
#                         US - RRE - Evergreen - Employers - 7.31                evergreen                 175
#                         US - RRE - Evergreen - Job Titles - 7.31               evergreen                 174
#                         US - RRE - Evergreen - Video Remarketing & LAL - 4.18  evergreen                 282
#                         US - RRE - Evergreen - Video Remarketing & LAL - 4.4   evergreen                 108
#                         US - RRE - Evergreen - Video Remarketing & LAL - 5.21  evergreen                   8
#                         US - RRE - Feb Promo - Agents & Brokers - LAL - 2.1    febpromo                  112
#                         US - RRE - Feb Promo - Opened Lead Forms LAL - 2.1     febpromo                   76
#                         US - RRE - Feb Promo - Video Remarketing & LAL - 2.1   febpromo                  252
#                         US - RRE - Opened Lead Forms LAL - Evergreen - 11.12   openedleadformlal         128
#                         US - RRE - Page Visitor Remarketing - CPC              pagevisitorremarketing    170
#                         US - RRE - Page Visitor Remarketing - oCPM             pagevisitorremarketing    449
#                         US - RRE - SQL LAL - Evergreen - 4.24                  sqllal                    256
#                         US - RRE - Video Remarketing  & LAL - 10.17            videoremarketinglal       128
#                         US - RRE - Website Remarketing - Evergreen - 4.10      websiteremarketing         36
#                         US - RRE - Website Remarketing - Evergreen - 4.18      websiteremarketing        132
#                         US - RRE - Website Remarketing LAL - Evergreen - 4.10  websiteremarketinglal      40
#                         US - RRE - Website Remarketing LAL - Evergreen - 4.19  websiteremarketinglal     128
# dtype: int64

# %%
fb['conversion']= fb[['lead_page_contains_thank-you']].astype(float)

# %%
def conversion_categ(df):
    if ((df.conversion>=0) & (df.conversion<=2)):
        return "btw 0 and 2 conversions"
    elif ((df.conversion>=3) & (df.conversion<=6)): 
        return "btw 3 and 6 conversions"
    elif ((df.conversion>=7) & (df.conversion<=12)): 
        return "btw 7 and 12 conversions"
    else:
        return 'more than 12 conversions'

# %%
fb['labels']=fb.apply(conversion_categ,axis=1)

# %%
def missing_values(df):
        mis = df.isnull().sum()
        mis_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis, mis_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(2)
        print ("df has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
missing_values(fb)
# Out:
# df has 43 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
np.unique(fb.age,return_counts=True)
# Out:
# (array(['18-24', '25-34', '35-44', '45-54', '55-64', '65+'], dtype=object),
#  array([ 5661, 24286, 24293, 24289, 23058,  4298]))

# %%
#repordering the columns
fb=fb[['ad_account_id', 'ad_account_name', 'reporting_starts',
       'reporting_ends', 'ad_set_name', 'age', 'ad_set_delivery', 'bid',
       'bid_type', 'ad_set_budget', 'ad_set_budget_type',
       'last_significant_edit', 'results', 'result_indicator', 'reach',
       'impressions', 'cost_per_results', 'amount_spent_(usd)', 'ends',
       'starts', 'link_clicks', 'website_purchases', 'leads_(form)',
       'campaign_name', 'campaign_id', 'lead_page_contains_thank-you',
       'lead_submission', 'ad_set_id', 'landing_page_views', 'session',
       'day_of_week', 'year', 'month', 'week_num', 'location', 'topic', 'type',
       'target', 'target_sub', 'version', 'target_grouped', 'conversion',
       'labels']]

# %%
def unique_val_count(a):
    unique, inverse = np.unique(a, return_inverse=True)
    count = np.zeros(len(unique), np.int)
    np.add.at(count, inverse, 1)
    return np.vstack((unique, count)).T

# %%
fb['location'].value_counts()
# Out:
# US             45508
# EMEA           31918
# UK              7396
# MX              5941
# DE              5630
# FR              3439
# CA              2095
# AU              1703
# ZA              1594
# ES               372
# IT               112
# BoostedPost      112
# SE                65
# Name: location, dtype: int64

# %%
fb.head()
# Out:
#         ad_account_id ad_account_name reporting_starts reporting_ends  \
# 7797  971415906232505      Matterport       2019-09-03     2019-09-03
# 7786  971415906232505      Matterport       2019-09-03     2019-09-03
# 7776  971415906232505      Matterport       2019-09-03     2019-09-03
# 7777  971415906232505      Matterport       2019-09-03     2019-09-03
# 7778  971415906232505      Matterport       2019-09-03     2019-09-03
#
#                                             ad_set_name    age  \
# 7797              ES - PS - Evergreen - All Lists - 5.1  55-64
# 7786  UK - PS - Evergreen - Video & Website Remarket...  25-34
# 7776               UK - PS - Evergreen - SQL LAL - 5.23  25-34
# 7777               UK - PS - Evergreen - SQL LAL - 5.23  18-24
# 7778      UK - PS - Evergreen - Camera Sales LAL - 5.23  55-64
#
#      ad_set_delivery  bid       bid_type  ad_set_budget ad_set_budget_type  \
# 7797          active    0  ABSOLUTE_OCPM           25.0              Daily
# 7786          active    0  ABSOLUTE_OCPM          400.0              Daily
# 7776          active    0  ABSOLUTE_OCPM           50.0              Daily
# 7777          active    0  ABSOLUTE_OCPM           50.0              Daily
# 7778          active    0  ABSOLUTE_OCPM           50.0              Daily
#
#          last_significant_edit  results  \
# 7797  2019-08-16T12:52:16-0700      0.0
# 7786  2019-09-01T21:29:38-0700      1.0
# 7776  2019-09-01T21:31:22-0700      0.0
# 7777  2019-09-01T21:31:22-0700      0.0
# 7778  2019-09-01T21:31:14-0700      0.0
#
#                                        result_indicator  reach  impressions  \
# 7797                                            novalue    139          162
# 7786  actions:offsite_conversion.custom.109991576318312   8480         9509
# 7776                                            novalue    956         1009
# 7777                                            novalue    127          139
# 7778                                            novalue     63           66
#
#       cost_per_results  amount_spent_(usd)     ends starts  link_clicks  \
# 7797              0.00                0.93  Ongoing  43586          0.0
# 7786            113.32              113.32  Ongoing  43608         52.0
# 7776              0.00                9.21  Ongoing  43608          7.0
# 7777              0.00                1.03  Ongoing  43608          0.0
# 7778              0.00                1.08  Ongoing  43608          0.0
#
#       website_purchases  leads_(form)               campaign_name  \
# 7797                0.0           0.0  EMEA-ES-PS-LeadSubmissions
# 7786                0.0           0.0  EMEA-UK-PS-LeadSubmissions
# 7776                0.0           0.0  EMEA-UK-PS-LeadSubmissions
# 7777                0.0           0.0  EMEA-UK-PS-LeadSubmissions
# 7778                0.0           0.0  EMEA-UK-PS-LeadSubmissions
#
#         campaign_id  lead_page_contains_thank-you  lead_submission  \
# 7797  6074860433239                           0.0              0.0
# 7786  6058738984839                           1.0              0.0
# 7776  6058738984839                           0.0              0.0
# 7777  6058738984839                           0.0              0.0
# 7778  6058738984839                           0.0              0.0
#
#           ad_set_id  landing_page_views  session day_of_week  year  month  \
# 7797  6124979913439                 0.0  sheet10        Tues  2019      9
# 7786  6127430097839                37.0  sheet10        Tues  2019      9
# 7776  6127432339039                 4.0  sheet10        Tues  2019      9
# 7777  6127432339039                 0.0  sheet10        Tues  2019      9
# 7778  6127431430239                 0.0  sheet10        Tues  2019      9
#
#       week_num location topic type target   target_sub version target_grouped  \
# 7797        36     EMEA    ES   PS          Evergreen      5.1      evergreen
# 7786        36     EMEA    UK   PS          Evergreen     5.23      evergreen
# 7776        36     EMEA    UK   PS          Evergreen     5.23      evergreen
# 7777        36     EMEA    UK   PS          Evergreen     5.23      evergreen
# 7778        36     EMEA    UK   PS          Evergreen     5.23      evergreen
#
#       conversion                   labels
# 7797         0.0  btw 0 and 2 conversions
# 7786         1.0  btw 0 and 2 conversions
# 7776         0.0  btw 0 and 2 conversions
# 7777         0.0  btw 0 and 2 conversions
# 7778         0.0  btw 0 and 2 conversions

# %%
len(fb[((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('PS')))]['campaign_name'])
# Out:
# 25661

# %%
len(fb[((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('RRE')))]['campaign_name'])
# Out:
# 43602

# %%
fb[((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('PS'))) | 
       ((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('RRE')))]['campaign_name'].value_counts()
# Out:
# US-RRE-LeadSubmissions                 12697
# US-PS-LeadSubmissions                  10440
# EMEA-UK-PS-LeadSubmissions              5917
# EMEA-ES-RRE-LeadSubmissions             4912
# EMEA-FR-RRE-LeadSubmissions             4646
# MX-RRE-LatinAmerica-LeadSubmissions     4230
# EMEA-RRE-LeadSubmissions                3196
# DE-RRE-LeadSubmissions                  3130
# EMEA-FR-PS-LeadSubmissions              2658
# EMEA-ZA-PS-LeadSubmissions              2345
# UK-RRE-LeadSubmissions                  2145
# EMEA-PS-LeadSubmissions                 2125
# CA-RRE-LeadSubmissions                  2095
# EMEA-IT-RRE-LeadSubmissions             1928
# AU-RRE-LeadSubmissions                  1703
# ZA-RRE-LeadSubmissions                  1134
# EMEA-DE-PS-LeadSubmissions              1128
# EMEA-PL-RRE-LeadSubmissions              964
# EMEA-ES-PS-LeadSubmissions               485
# EMEA-IT-PS-LeadSubmissions               359
# US-RRE-P1Areas-LeadSubmissions           297
# EMEA-UK-RRE-LeadSubmissions              260
# MX-PS-LATAM-LeadSubmissions              204
# EMEA-DE-RRE-LeadSubmissions              115
# US-RRE-Device-LeadSubmissions             85
# SE-RRE-LeadSubmissions                    65
# Name: campaign_name, dtype: int64

# %%
len(fb[((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('PS'))) | 
       ((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('RRE')))]['campaign_name'])
# Out:
# 69263

# %%
fb[~(((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('PS'))) | 
       ((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('RRE'))))]['campaign_name'].value_counts()
# Out:
# US-PS-LeadAds-2018                                                             4220
# US-AEC-LeadSubmissions                                                         3843
# US-MSP-Reach-Awareness                                                         1835
# US-TH-LeadSubmissions                                                          1813
# US-Cloud-Awareness                                                             1624
# FR-RRE-Reach-Awareness                                                         1579
# US-INS-LeadSubmissions                                                         1507
# MX-RRE-LatinAmerica-Awareness                                                  1475
# UK-PS-LeadAds-2018                                                             1456
# US-RRE-LeadAds-2018                                                            1444
# UK-PS-Awareness                                                                1361
# DE-PS-LeadAds-2018                                                             1236
# DE-RRE-LeadAds-2018                                                            1112
# UK-RRE-LeadAds-2018                                                            1064
# US-CRE-LeadAds-2018                                                            1032
# US-MF-LeadSubmissions                                                          1012
# FR-PS-LeadAds-2018                                                              996
# UK-RRE-Awareness                                                                916
# EMEA-ES-RRE-Awareness                                                           880
# FR-RRE-LeadAds-2018                                                             796
# US-GEN-LeadSubmissions                                                          637
# US-INS-Reach-Awareness                                                          504
# ZA-RRE-LeadAds-2018                                                             460
# US-Cloud3.0-Conversions                                                         360
# US-Cloud3.0-Awareness                                                           360
# US-CRE-LeadSubmissions                                                          356
# US-TH-LeadAds-2018                                                              312
# US-MF-LeadAds-2018                                                              292
# US-Cloud3.0-Webinar-360Camera                                                   203
# ES-RRE-LeadAds-2018                                                             192
# US-RRE-Reach-Awareness-Pro2Lite                                                 160
# UK-PS-Webinar-OpeningDoors                                                      115
# US-PS-Webinar-OpeningDoors                                                      115
# IT-RRE-LeadAds-2018                                                             112
# ES-PS-LeadAds-2018                                                              112
# US-INS-Webinar-ChicagoWater&FireRestoration                                      96
# UK-Cloud3.0-Conversions                                                          90
# US-8.21Meetup-Conversions                                                        90
# DE-RRE-Awareness                                                                 84
# US-PS-Webinar-9.11Webinar2                                                       70
# UK-PS-Webinar-9.11Webinar2                                                       70
# US-RRE-Awareness-DecemberSale                                                    68
# ES-RRE-Awareness-DecemberSale                                                    68
# FR-RRE-Awareness-DecemberSale                                                    68
# DE-RRE-Awareness-DecemberSale                                                    68
# UK-RRE-Awareness-DecemberSale                                                    68
# UK-PS-Awareness-ReachFrequency                                                   60
# BoostedPost-Event:Webinar-ListingPresentationPanelDiscussion                     56
# UK-Cloud3.0-Webinar-360Camera                                                    51
# MX-RRE-LatinAmerica-Awareness-ReachFrequency                                     32
# US-RRE-Awareness-ReachFrequency                                                  28
# BoostedPost-Event:Webinar-Accurate,CompetitiveEstimationforConstructionPros      28
# BoostedPost-Event:Webinar-3DRealityCaptureforArchitects                          28
# US-RRE-FlashSale                                                                  8
# Name: campaign_name, dtype: int64

# %%
len(fb[(fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('AEC'))])
# Out:
# 3843

# %%
fb_ls = fb[((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('PS'))) | 
       ((fb.campaign_name.str.contains('LeadSubmissions')) & (fb.campaign_name.str.contains('RRE')))]

# %%
len(fb_ls)
# Out:
# 69263

# %%
fb_ls.reset_index(drop = True, inplace = True)

# %%
fb_ls
# Out:
#          ad_account_id ad_account_name reporting_starts reporting_ends  \
# 0      971415906232505      Matterport       2019-09-03     2019-09-03
# 1      971415906232505      Matterport       2019-09-03     2019-09-03
# 2      971415906232505      Matterport       2019-09-03     2019-09-03
# 3      971415906232505      Matterport       2019-09-03     2019-09-03
# 4      971415906232505      Matterport       2019-09-03     2019-09-03
# 5      971415906232505      Matterport       2019-09-03     2019-09-03
# 6      971415906232505      Matterport       2019-09-03     2019-09-03
# 7      971415906232505      Matterport       2019-09-03     2019-09-03
# 8      971415906232505      Matterport       2019-09-03     2019-09-03
# 9      971415906232505      Matterport       2019-09-03     2019-09-03
# 10     971415906232505      Matterport       2019-09-03     2019-09-03
# 11     971415906232505      Matterport       2019-09-03     2019-09-03
# 12     971415906232505      Matterport       2019-09-03     2019-09-03
# 13     971415906232505      Matterport       2019-09-03     2019-09-03
# 14     971415906232505      Matterport       2019-09-03     2019-09-03
# 15     971415906232505      Matterport       2019-09-03     2019-09-03
# 16     971415906232505      Matterport       2019-09-03     2019-09-03
# 17     971415906232505      Matterport       2019-09-03     2019-09-03
# 18     971415906232505      Matterport       2019-09-03     2019-09-03
# 19     971415906232505      Matterport       2019-09-03     2019-09-03
# 20     971415906232505      Matterport       2019-09-03     2019-09-03
# 21     971415906232505      Matterport       2019-09-03     2019-09-03
# 22     971415906232505      Matterport       2019-09-03     2019-09-03
# 23     971415906232505      Matterport       2019-09-03     2019-09-03
# 24     971415906232505      Matterport       2019-09-03     2019-09-03
# 25     971415906232505      Matterport       2019-09-03     2019-09-03
# 26     971415906232505      Matterport       2019-09-03     2019-09-03
# 27     971415906232505      Matterport       2019-09-03     2019-09-03
# 28     971415906232505      Matterport       2019-09-03     2019-09-03
# 29     971415906232505      Matterport       2019-09-03     2019-09-03
# ...                ...             ...              ...            ...
# 69233  971415906232505      Matterport       2018-01-01     2018-01-01
# 69234  971415906232505      Matterport       2018-01-01     2018-01-01
# 69235  971415906232505      Matterport       2018-01-01     2018-01-01
# 69236  971415906232505      Matterport       2018-01-01     2018-01-01
# 69237  971415906232505      Matterport       2018-01-01     2018-01-01
# 69238  971415906232505      Matterport       2018-01-01     2018-01-01
# 69239  971415906232505      Matterport       2018-01-01     2018-01-01
# 69240  971415906232505      Matterport       2018-01-01     2018-01-01
# 69241  971415906232505      Matterport       2018-01-01     2018-01-01
# 69242  971415906232505      Matterport       2018-01-01     2018-01-01
# 69243  971415906232505      Matterport       2018-01-01     2018-01-01
# 69244  971415906232505      Matterport       2018-01-01     2018-01-01
# 69245  971415906232505      Matterport       2018-01-01     2018-01-01
# 69246  971415906232505      Matterport       2018-01-01     2018-01-01
# 69247  971415906232505      Matterport       2018-01-01     2018-01-01
# 69248  971415906232505      Matterport       2018-01-01     2018-01-01
# 69249  971415906232505      Matterport       2018-01-01     2018-01-01
# 69250  971415906232505      Matterport       2018-01-01     2018-01-01
# 69251  971415906232505      Matterport       2018-01-01     2018-01-01
# 69252  971415906232505      Matterport       2018-01-01     2018-01-01
# 69253  971415906232505      Matterport       2018-01-01     2018-01-01
# 69254  971415906232505      Matterport       2018-01-01     2018-01-01
# 69255  971415906232505      Matterport       2018-01-01     2018-01-01
# 69256  971415906232505      Matterport       2018-01-01     2018-01-01
# 69257  971415906232505      Matterport       2018-01-01     2018-01-01
# 69258  971415906232505      Matterport       2018-01-01     2018-01-01
# 69259  971415906232505      Matterport       2018-01-01     2018-01-01
# 69260  971415906232505      Matterport       2018-01-01     2018-01-01
# 69261  971415906232505      Matterport       2018-01-01     2018-01-01
# 69262  971415906232505      Matterport       2018-01-01     2018-01-01
#
#                                              ad_set_name    age  \
# 0                  ES - PS - Evergreen - All Lists - 5.1  55-64
# 1      UK - PS - Evergreen - Video & Website Remarket...  25-34
# 2                   UK - PS - Evergreen - SQL LAL - 5.23  25-34
# 3                   UK - PS - Evergreen - SQL LAL - 5.23  18-24
# 4          UK - PS - Evergreen - Camera Sales LAL - 5.23  55-64
# 5          UK - PS - Evergreen - Camera Sales LAL - 5.23  45-54
# 6          UK - PS - Evergreen - Camera Sales LAL - 5.23  35-44
# 7          UK - PS - Evergreen - Camera Sales LAL - 5.23  25-34
# 8          UK - PS - Evergreen - Camera Sales LAL - 5.23  18-24
# 9      UK - PS - Evergreen - Video & Website Remarket...  55-64
# 10     UK - PS - Evergreen - Video & Website Remarket...  45-54
# 11     UK - PS - Evergreen - Video & Website Remarket...  35-44
# 12     UK - PS - Evergreen - Video & Website Remarket...  18-24
# 13                  UK - PS - Evergreen - SQL LAL - 5.23  45-54
# 14         US - PS - ENT Photography Entrepreneur - 5.22  55-64
# 15         US - PS - ENT Photography Entrepreneur - 5.22  45-54
# 16         US - PS - ENT Photography Entrepreneur - 5.22  35-44
# 17         US - PS - ENT Photography Entrepreneur - 5.22  25-34
# 18         US - PS - ENT Photography Entrepreneur - 5.22  18-24
# 19                 ES - PS - Evergreen - All Lists - 5.1  45-54
# 20                  UK - PS - Evergreen - SQL LAL - 5.23  35-44
# 21                  UK - PS - Evergreen - SQL LAL - 5.23  55-64
# 22                            IT - PS - All Lists - 5.28  35-44
# 23            US - RRE - Page Visitor Remarketing - oCPM    65+
# 24            US - RRE - Page Visitor Remarketing - oCPM  55-64
# 25            US - RRE - Page Visitor Remarketing - oCPM  45-54
# 26            US - RRE - Page Visitor Remarketing - oCPM  35-44
# 27            US - RRE - Page Visitor Remarketing - oCPM  25-34
# 28                            IT - PS - All Lists - 5.28  55-64
# 29                            IT - PS - All Lists - 5.28  45-54
# ...                                                  ...    ...
# 69233                 US - ENT - Self Employed / Drivers  25-34
# 69234                              FR - FR Website - LAL  25-34
# 69235                 US - ENT - Self Employed / Drivers  18-24
# 69236                         DE - DE Remax Agents - LAL  55-64
# 69237                              FR - FR Website - LAL  55-64
# 69238                         DE - DE Remax Agents - LAL  35-44
# 69239                         DE - DE Remax Agents - LAL  25-34
# 69240                     MX - Retargeting Website - LAL  55-64
# 69241                     MX - Retargeting Website - LAL  45-54
# 69242                 US - ENT - Self Employed / Drivers  45-54
# 69243                 US - ENT - Self Employed / Drivers  55-64
# 69244                                FR - PS - SQL - LAL  35-44
# 69245                                DE ROW -  MQL - LAL  25-34
# 69246                                FR - PS - SQL - LAL  25-34
# 69247                                DE ROW -  MQL - LAL  55-64
# 69248                          ZA - PS - MQL & SQL - LAL  55-64
# 69249                                DE ROW -  MQL - LAL  45-54
# 69250                          ZA - PS - MQL & SQL - LAL  45-54
# 69251                                DE ROW -  MQL - LAL  35-44
# 69252                          ZA - PS - MQL & SQL - LAL  35-44
# 69253                          ZA - PS - MQL & SQL - LAL  25-34
# 69254                     ZA - ZA Site Retargeting - LAL  25-34
# 69255            MX - Latin America - Remax Agents - LAL  55-64
# 69256                     ZA - ZA Site Retargeting - LAL  55-64
# 69257            MX - Latin America - Remax Agents - LAL  45-54
# 69258                     ZA - ZA Site Retargeting - LAL  45-54
# 69259            MX - Latin America - Remax Agents - LAL  35-44
# 69260                     ZA - ZA Site Retargeting - LAL  35-44
# 69261            MX - Latin America - Remax Agents - LAL  25-34
# 69262                           FR ROW - RRE - MQL - LAL  25-34
#
#       ad_set_delivery  bid       bid_type  ad_set_budget ad_set_budget_type  \
# 0              active    0  ABSOLUTE_OCPM           25.0              Daily
# 1              active    0  ABSOLUTE_OCPM          400.0              Daily
# 2              active    0  ABSOLUTE_OCPM           50.0              Daily
# 3              active    0  ABSOLUTE_OCPM           50.0              Daily
# 4              active    0  ABSOLUTE_OCPM           50.0              Daily
# 5              active    0  ABSOLUTE_OCPM           50.0              Daily
# 6              active    0  ABSOLUTE_OCPM           50.0              Daily
# 7              active    0  ABSOLUTE_OCPM           50.0              Daily
# 8              active    0  ABSOLUTE_OCPM           50.0              Daily
# 9              active    0  ABSOLUTE_OCPM          400.0              Daily
# 10             active    0  ABSOLUTE_OCPM          400.0              Daily
# 11             active    0  ABSOLUTE_OCPM          400.0              Daily
# 12             active    0  ABSOLUTE_OCPM          400.0              Daily
# 13             active    0  ABSOLUTE_OCPM           50.0              Daily
# 14             active    0  ABSOLUTE_OCPM         2200.0              Daily
# 15             active    0  ABSOLUTE_OCPM         2200.0              Daily
# 16             active    0  ABSOLUTE_OCPM         2200.0              Daily
# 17             active    0  ABSOLUTE_OCPM         2200.0              Daily
# 18             active    0  ABSOLUTE_OCPM         2200.0              Daily
# 19             active    0  ABSOLUTE_OCPM           25.0              Daily
# 20             active    0  ABSOLUTE_OCPM           50.0              Daily
# 21             active    0  ABSOLUTE_OCPM           50.0              Daily
# 22             active    0  ABSOLUTE_OCPM          150.0              Daily
# 23             active    0  ABSOLUTE_OCPM          250.0              Daily
# 24             active    0  ABSOLUTE_OCPM          250.0              Daily
# 25             active    0  ABSOLUTE_OCPM          250.0              Daily
# 26             active    0  ABSOLUTE_OCPM          250.0              Daily
# 27             active    0  ABSOLUTE_OCPM          250.0              Daily
# 28             active    0  ABSOLUTE_OCPM          150.0              Daily
# 29             active    0  ABSOLUTE_OCPM          150.0              Daily
# ...               ...  ...            ...            ...                ...
# 69233        inactive    0  ABSOLUTE_OCPM          250.0              Daily
# 69234        inactive    0  ABSOLUTE_OCPM          100.0              Daily
# 69235        inactive    0  ABSOLUTE_OCPM          250.0              Daily
# 69236        inactive    0  ABSOLUTE_OCPM           53.0              Daily
# 69237        inactive    0  ABSOLUTE_OCPM          100.0              Daily
# 69238        inactive    0  ABSOLUTE_OCPM           53.0              Daily
# 69239        inactive    0  ABSOLUTE_OCPM           53.0              Daily
# 69240        inactive    0  ABSOLUTE_OCPM           30.0              Daily
# 69241        inactive    0  ABSOLUTE_OCPM           30.0              Daily
# 69242        inactive    0  ABSOLUTE_OCPM          250.0              Daily
# 69243        inactive    0  ABSOLUTE_OCPM          250.0              Daily
# 69244        inactive    0  ABSOLUTE_OCPM          200.0              Daily
# 69245        inactive    0  ABSOLUTE_OCPM           53.0              Daily
# 69246        inactive    0  ABSOLUTE_OCPM          200.0              Daily
# 69247        inactive    0  ABSOLUTE_OCPM           53.0              Daily
# 69248        inactive    0  ABSOLUTE_OCPM           75.0              Daily
# 69249        inactive    0  ABSOLUTE_OCPM           53.0              Daily
# 69250        inactive    0  ABSOLUTE_OCPM           75.0              Daily
# 69251        inactive    0  ABSOLUTE_OCPM           53.0              Daily
# 69252        inactive    0  ABSOLUTE_OCPM           75.0              Daily
# 69253        inactive    0  ABSOLUTE_OCPM           75.0              Daily
# 69254        inactive    0  ABSOLUTE_OCPM           57.0              Daily
# 69255        inactive    0  ABSOLUTE_OCPM           31.0              Daily
# 69256        inactive    0  ABSOLUTE_OCPM           57.0              Daily
# 69257        inactive    0  ABSOLUTE_OCPM           31.0              Daily
# 69258        inactive    0  ABSOLUTE_OCPM           57.0              Daily
# 69259        inactive    0  ABSOLUTE_OCPM           31.0              Daily
# 69260        inactive    0  ABSOLUTE_OCPM           57.0              Daily
# 69261        inactive    0  ABSOLUTE_OCPM           31.0              Daily
# 69262        inactive    0  ABSOLUTE_OCPM           56.0              Daily
#
#           last_significant_edit  results  \
# 0      2019-08-16T12:52:16-0700      0.0
# 1      2019-09-01T21:29:38-0700      1.0
# 2      2019-09-01T21:31:22-0700      0.0
# 3      2019-09-01T21:31:22-0700      0.0
# 4      2019-09-01T21:31:14-0700      0.0
# 5      2019-09-01T21:31:14-0700      1.0
# 6      2019-09-01T21:31:14-0700      0.0
# 7      2019-09-01T21:31:14-0700      1.0
# 8      2019-09-01T21:31:14-0700      0.0
# 9      2019-09-01T21:29:38-0700      0.0
# 10     2019-09-01T21:29:38-0700      4.0
# 11     2019-09-01T21:29:38-0700      2.0
# 12     2019-09-01T21:29:38-0700      0.0
# 13     2019-09-01T21:31:22-0700      0.0
# 14     2019-09-01T21:26:55-0700      3.0
# 15     2019-09-01T21:26:55-0700     20.0
# 16     2019-09-01T21:26:55-0700     18.0
# 17     2019-09-01T21:26:55-0700      6.0
# 18     2019-09-01T21:26:55-0700      5.0
# 19     2019-08-16T12:52:16-0700      1.0
# 20     2019-09-01T21:31:22-0700      2.0
# 21     2019-09-01T21:31:22-0700      1.0
# 22     2019-09-03T16:11:06-0700      1.0
# 23     2019-09-01T21:29:45-0700      0.0
# 24     2019-09-01T21:29:45-0700      0.0
# 25     2019-09-01T21:29:45-0700      1.0
# 26     2019-09-01T21:29:45-0700      0.0
# 27     2019-09-01T21:29:45-0700      1.0
# 28     2019-09-03T16:11:06-0700      0.0
# 29     2019-09-03T16:11:06-0700      0.0
# ...                         ...      ...
# 69233  2018-07-13T11:28:09-0700      1.0
# 69234  2018-03-12T18:23:31-0700      0.0
# 69235  2018-07-13T11:28:09-0700      0.0
# 69236  2018-03-12T16:54:29-0700      0.0
# 69237  2018-03-12T18:23:31-0700      0.0
# 69238  2018-03-12T16:54:29-0700      1.0
# 69239  2018-03-12T16:54:29-0700      0.0
# 69240  2018-03-12T16:33:07-0700      1.0
# 69241  2018-03-12T16:33:07-0700      7.0
# 69242  2018-07-13T11:28:09-0700      2.0
# 69243  2018-07-13T11:28:09-0700      0.0
# 69244  2018-03-12T14:16:20-0700      0.0
# 69245  2018-03-12T16:54:29-0700      0.0
# 69246  2018-03-12T14:16:20-0700      0.0
# 69247  2018-03-12T16:54:29-0700      0.0
# 69248  2018-07-09T16:28:16-0700      0.0
# 69249  2018-03-12T16:54:29-0700      0.0
# 69250  2018-07-09T16:28:16-0700      2.0
# 69251  2018-03-12T16:54:29-0700      2.0
# 69252  2018-07-09T16:28:16-0700      1.0
# 69253  2018-07-09T16:28:16-0700      2.0
# 69254  2018-03-12T16:26:43-0700      0.0
# 69255  2018-08-27T12:19:42-0700      0.0
# 69256  2018-03-12T16:26:43-0700      0.0
# 69257  2018-08-27T12:19:42-0700      5.0
# 69258  2018-03-12T16:26:43-0700      1.0
# 69259  2018-08-27T12:19:42-0700      3.0
# 69260  2018-03-12T16:26:43-0700      1.0
# 69261  2018-08-27T12:19:42-0700      4.0
# 69262  2018-03-12T18:15:45-0700      0.0
#
#                                         result_indicator  reach  impressions  \
# 0                                                novalue    139          162
# 1      actions:offsite_conversion.custom.109991576318312   8480         9509
# 2                                                novalue    956         1009
# 3                                                novalue    127          139
# 4                                                novalue     63           66
# 5      actions:offsite_conversion.custom.109991576318312    992         1093
# 6                                                novalue   1386         1545
# 7      actions:offsite_conversion.custom.109991576318312   1521         1656
# 8                                                novalue    137          157
# 9                                                novalue    256          392
# 10     actions:offsite_conversion.custom.109991576318312   7104         8045
# 11     actions:offsite_conversion.custom.109991576318312   9256        10186
# 12                                               novalue    816          966
# 13                                               novalue   1022         1101
# 14     actions:offsite_conversion.custom.109991576318312   3232         3729
# 15     actions:offsite_conversion.custom.109991576318312  34976        36579
# 16     actions:offsite_conversion.custom.109991576318312  53152        56920
# 17     actions:offsite_conversion.custom.109991576318312  55904        58121
# 18     actions:offsite_conversion.custom.109991576318312   8480         9227
# 19     actions:offsite_conversion.custom.109991576318312   1661         1883
# 20     actions:offsite_conversion.custom.109991576318312   1561         1653
# 21     actions:offsite_conversion.custom.109991576318312     69           76
# 22     actions:offsite_conversion.custom.109991576318312   3808         4016
# 23                                               novalue    235          343
# 24                                               novalue    402          682
# 25     actions:offsite_conversion.custom.109991576318312    578         1086
# 26                                               novalue    605         1161
# 27     actions:offsite_conversion.custom.109991576318312    527         1049
# 28                                               novalue    224          327
# 29                                               novalue   3940         4525
# ...                                                  ...    ...          ...
# 69233  actions:offsite_conversion.custom.109991576318312   1833         2302
# 69234                                            novalue   1551         2710
# 69235                                            novalue    150          184
# 69236                                            novalue    162          179
# 69237                                            novalue     91          162
# 69238  actions:offsite_conversion.custom.109991576318312   1843         1998
# 69239                                            novalue   1055         1136
# 69240  actions:offsite_conversion.custom.109991576318312    340          380
# 69241  actions:offsite_conversion.custom.109991576318312   5055         5920
# 69242  actions:offsite_conversion.custom.109991576318312   1268         1630
# 69243                                            novalue     90           90
# 69244                                            novalue   1366         1697
# 69245                                            novalue   1566         1883
# 69246                                            novalue    568          681
# 69247                                            novalue    104          163
# 69248                                            novalue    234          340
# 69249                                            novalue   1714         2045
# 69250  actions:offsite_conversion.custom.109991576318312   3254         4367
# 69251  actions:offsite_conversion.custom.109991576318312   2198         2536
# 69252  actions:offsite_conversion.custom.109991576318312   3270         4409
# 69253  actions:offsite_conversion.custom.109991576318312   2372         3200
# 69254                                            novalue   1670         2132
# 69255                                            novalue    720          755
# 69256                                            novalue    264          299
# 69257  actions:offsite_conversion.custom.109991576318312   8783        10149
# 69258  actions:offsite_conversion.custom.109991576318312   3302         4214
# 69259  actions:offsite_conversion.custom.109991576318312   9535        10656
# 69260  actions:offsite_conversion.custom.109991576318312   3892         4863
# 69261  actions:offsite_conversion.custom.109991576318312   4327         4577
# 69262                                            novalue   1302         1669
#
#        cost_per_results  amount_spent_(usd)     ends               starts  \
# 0              0.000000            0.930000  Ongoing                43586
# 1            113.320000          113.320000  Ongoing                43608
# 2              0.000000            9.210000  Ongoing                43608
# 3              0.000000            1.030000  Ongoing                43608
# 4              0.000000            1.080000  Ongoing                43608
# 5             14.750000           14.750000  Ongoing                43608
# 6              0.000000           16.640000  Ongoing                43608
# 7             16.720000           16.720000  Ongoing                43608
# 8              0.000000            1.290000  Ongoing                43608
# 9              0.000000            9.000000  Ongoing                43608
# 10            33.452500          133.810000  Ongoing                43608
# 11            70.090000          140.180000  Ongoing                43608
# 12             0.000000            9.670000  Ongoing                43608
# 13             0.000000           16.430000  Ongoing                43608
# 14            30.103333           90.310000  Ongoing                43601
# 15            37.459000          749.180000  Ongoing                43601
# 16            42.161111          758.900000  Ongoing                43601
# 17            84.646667          507.880000  Ongoing                43601
# 18            12.672000           63.360000  Ongoing                43601
# 19            10.490000           10.490000  Ongoing                43586
# 20            11.090000           22.180000  Ongoing                43608
# 21             1.670000            1.670000  Ongoing                43608
# 22            18.060000           18.060000  Ongoing                43613
# 23             0.000000           35.180000  Ongoing                43622
# 24             0.000000           49.440000  Ongoing                43622
# 25            65.910000           65.910000  Ongoing                43622
# 26             0.000000           48.450000  Ongoing                43622
# 27            35.810000           35.810000  Ongoing                43622
# 28             0.000000            2.320000  Ongoing                43613
# 29             0.000000           32.250000  Ongoing                43613
# ...                 ...                 ...      ...                  ...
# 69233         22.864944           22.864944  Ongoing  2017-12-13 00:00:00
# 69234          0.000000           26.134903  Ongoing  2017-07-05 00:00:00
# 69235          0.000000            1.319708  Ongoing  2017-12-13 00:00:00
# 69236          0.000000            2.590000  Ongoing  2017-06-22 00:00:00
# 69237          0.000000            2.599493  Ongoing  2017-07-05 00:00:00
# 69238         23.190000           23.190000  Ongoing  2017-06-22 00:00:00
# 69239          0.000000           10.030000  Ongoing  2017-06-22 00:00:00
# 69240          1.520000            1.520000  Ongoing  2017-06-22 00:00:00
# 69241          2.602857           18.220000  Ongoing  2017-06-22 00:00:00
# 69242         15.846496           31.692992  Ongoing  2017-12-13 00:00:00
# 69243          0.000000            1.789604  Ongoing  2017-12-13 00:00:00
# 69244          0.000000            7.710000  Ongoing  2017-07-18 00:00:00
# 69245          0.000000           13.640000  Ongoing  2017-12-19 00:00:00
# 69246          0.000000            2.740000  Ongoing  2017-07-18 00:00:00
# 69247          0.000000            2.430000  Ongoing  2017-12-19 00:00:00
# 69248          0.000000            1.770000  Ongoing  2017-07-10 00:00:00
# 69249          0.000000           26.170000  Ongoing  2017-12-19 00:00:00
# 69250          9.380000           18.760000  Ongoing  2017-07-10 00:00:00
# 69251         11.675000           23.350000  Ongoing  2017-12-19 00:00:00
# 69252         16.450000           16.450000  Ongoing  2017-07-10 00:00:00
# 69253          5.280000           10.560000  Ongoing  2017-07-10 00:00:00
# 69254          0.000000            8.038543  Ongoing  2017-07-07 00:00:00
# 69255          0.000000            1.729656  Ongoing  2017-12-18 00:00:00
# 69256          0.000000            1.639703  Ongoing  2017-07-07 00:00:00
# 69257          4.371132           21.855659  Ongoing  2017-12-18 00:00:00
# 69258         23.395760           23.395760  Ongoing  2017-07-07 00:00:00
# 69259          6.885299           20.655898  Ongoing  2017-12-18 00:00:00
# 69260         22.105994           22.105994  Ongoing  2017-07-07 00:00:00
# 69261          1.527197            6.108787  Ongoing  2017-12-18 00:00:00
# 69262          0.000000           10.710000  Ongoing  2017-12-19 00:00:00
#
#        link_clicks  website_purchases  leads_(form)  \
# 0              0.0                0.0           0.0
# 1             52.0                0.0           0.0
# 2              7.0                0.0           0.0
# 3              0.0                0.0           0.0
# 4              0.0                0.0           0.0
# 5              5.0                0.0           0.0
# 6             10.0                0.0           0.0
# 7             10.0                0.0           0.0
# 8              1.0                0.0           0.0
# 9              3.0                0.0           0.0
# 10            64.0                0.0           0.0
# 11            55.0                0.0           0.0
# 12             2.0                0.0           0.0
# 13            11.0                0.0           0.0
# 14            42.0                0.0           0.0
# 15           438.0                0.0           0.0
# 16           479.0                0.0           0.0
# 17           308.0                1.0           0.0
# 18            41.0                0.0           0.0
# 19            16.0                0.0           0.0
# 20            14.0                0.0           0.0
# 21             3.0                0.0           0.0
# 22            63.0                0.0           0.0
# 23             6.0                0.0           0.0
# 24            13.0                0.0           0.0
# 25            12.0                0.0           0.0
# 26             8.0                0.0           0.0
# 27            13.0                0.0           0.0
# 28             8.0                0.0           0.0
# 29            90.0                0.0           0.0
# ...            ...                ...           ...
# 69233         27.0                0.0           0.0
# 69234         11.0                0.0           0.0
# 69235          1.0                0.0           0.0
# 69236          1.0                0.0           0.0
# 69237          2.0                0.0           0.0
# 69238         32.0                0.0           0.0
# 69239         10.0                0.0           0.0
# 69240          8.0                0.0           0.0
# 69241         97.0                0.0           0.0
# 69242         29.0                0.0           0.0
# 69243          1.0                0.0           0.0
# 69244         13.0                0.0           0.0
# 69245         29.0                0.0           0.0
# 69246          6.0                0.0           0.0
# 69247          5.0                0.0           0.0
# 69248          6.0                0.0           0.0
# 69249         32.0                0.0           0.0
# 69250         49.0                0.0           0.0
# 69251         47.0                0.0           0.0
# 69252         34.0                0.0           0.0
# 69253         17.0                0.0           0.0
# 69254         12.0                0.0           0.0
# 69255         15.0                0.0           0.0
# 69256          4.0                0.0           0.0
# 69257        179.0                0.0           0.0
# 69258         34.0                0.0           0.0
# 69259        188.0                0.0           0.0
# 69260         25.0                0.0           0.0
# 69261         53.0                0.0           0.0
# 69262          7.0                0.0           0.0
#
#                              campaign_name    campaign_id  \
# 0               EMEA-ES-PS-LeadSubmissions  6074860433239
# 1               EMEA-UK-PS-LeadSubmissions  6058738984839
# 2               EMEA-UK-PS-LeadSubmissions  6058738984839
# 3               EMEA-UK-PS-LeadSubmissions  6058738984839
# 4               EMEA-UK-PS-LeadSubmissions  6058738984839
# 5               EMEA-UK-PS-LeadSubmissions  6058738984839
# 6               EMEA-UK-PS-LeadSubmissions  6058738984839
# 7               EMEA-UK-PS-LeadSubmissions  6058738984839
# 8               EMEA-UK-PS-LeadSubmissions  6058738984839
# 9               EMEA-UK-PS-LeadSubmissions  6058738984839
# 10              EMEA-UK-PS-LeadSubmissions  6058738984839
# 11              EMEA-UK-PS-LeadSubmissions  6058738984839
# 12              EMEA-UK-PS-LeadSubmissions  6058738984839
# 13              EMEA-UK-PS-LeadSubmissions  6058738984839
# 14                   US-PS-LeadSubmissions  6054174550039
# 15                   US-PS-LeadSubmissions  6054174550039
# 16                   US-PS-LeadSubmissions  6054174550039
# 17                   US-PS-LeadSubmissions  6054174550039
# 18                   US-PS-LeadSubmissions  6054174550039
# 19              EMEA-ES-PS-LeadSubmissions  6074860433239
# 20              EMEA-UK-PS-LeadSubmissions  6058738984839
# 21              EMEA-UK-PS-LeadSubmissions  6058738984839
# 22              EMEA-IT-PS-LeadSubmissions  6084287826639
# 23                  US-RRE-LeadSubmissions  6030854217839
# 24                  US-RRE-LeadSubmissions  6030854217839
# 25                  US-RRE-LeadSubmissions  6030854217839
# 26                  US-RRE-LeadSubmissions  6030854217839
# 27                  US-RRE-LeadSubmissions  6030854217839
# 28              EMEA-IT-PS-LeadSubmissions  6084287826639
# 29              EMEA-IT-PS-LeadSubmissions  6084287826639
# ...                                    ...            ...
# 69233                US-PS-LeadSubmissions  6054174550039
# 69234          EMEA-FR-RRE-LeadSubmissions  6072451432239
# 69235                US-PS-LeadSubmissions  6054174550039
# 69236               DE-RRE-LeadSubmissions  6072804296639
# 69237          EMEA-FR-RRE-LeadSubmissions  6072451432239
# 69238               DE-RRE-LeadSubmissions  6072804296639
# 69239               DE-RRE-LeadSubmissions  6072804296639
# 69240  MX-RRE-LatinAmerica-LeadSubmissions  6074910940839
# 69241  MX-RRE-LatinAmerica-LeadSubmissions  6074910940839
# 69242                US-PS-LeadSubmissions  6054174550039
# 69243                US-PS-LeadSubmissions  6054174550039
# 69244           EMEA-FR-PS-LeadSubmissions  6076580331439
# 69245               DE-RRE-LeadSubmissions  6072804296639
# 69246           EMEA-FR-PS-LeadSubmissions  6076580331439
# 69247               DE-RRE-LeadSubmissions  6072804296639
# 69248           EMEA-ZA-PS-LeadSubmissions  6076202444439
# 69249               DE-RRE-LeadSubmissions  6072804296639
# 69250           EMEA-ZA-PS-LeadSubmissions  6076202444439
# 69251               DE-RRE-LeadSubmissions  6072804296639
# 69252           EMEA-ZA-PS-LeadSubmissions  6076202444439
# 69253           EMEA-ZA-PS-LeadSubmissions  6076202444439
# 69254               ZA-RRE-LeadSubmissions  6075623594039
# 69255  MX-RRE-LatinAmerica-LeadSubmissions  6074910940839
# 69256               ZA-RRE-LeadSubmissions  6075623594039
# 69257  MX-RRE-LatinAmerica-LeadSubmissions  6074910940839
# 69258               ZA-RRE-LeadSubmissions  6075623594039
# 69259  MX-RRE-LatinAmerica-LeadSubmissions  6074910940839
# 69260               ZA-RRE-LeadSubmissions  6075623594039
# 69261  MX-RRE-LatinAmerica-LeadSubmissions  6074910940839
# 69262          EMEA-FR-RRE-LeadSubmissions  6072451432239
#
#        lead_page_contains_thank-you  lead_submission      ad_set_id  \
# 0                               0.0              0.0  6124979913439
# 1                               1.0              0.0  6127430097839
# 2                               0.0              0.0  6127432339039
# 3                               0.0              0.0  6127432339039
# 4                               0.0              0.0  6127431430239
# 5                               1.0              0.0  6127431430239
# 6                               0.0              0.0  6127431430239
# 7                               1.0              0.0  6127431430239
# 8                               0.0              0.0  6127431430239
# 9                               0.0              0.0  6127430097839
# 10                              4.0              0.0  6127430097839
# 11                              2.0              0.0  6127430097839
# 12                              0.0              0.0  6127430097839
# 13                              0.0              0.0  6127432339039
# 14                              3.0              3.0  6126598149239
# 15                             20.0             17.0  6126598149239
# 16                             18.0             14.0  6126598149239
# 17                              6.0              6.0  6126598149239
# 18                              5.0              4.0  6126598149239
# 19                              1.0              0.0  6124979913439
# 20                              2.0              0.0  6127432339039
# 21                              1.0              0.0  6127432339039
# 22                              1.0              0.0  6127908687239
# 23                              0.0              0.0  6128769325039
# 24                              0.0              0.0  6128769325039
# 25                              1.0              0.0  6128769325039
# 26                              0.0              0.0  6128769325039
# 27                              1.0              0.0  6128769325039
# 28                              0.0              0.0  6127908687239
# 29                              0.0              0.0  6127908687239
# ...                             ...              ...            ...
# 69233                           1.0              1.0  6086020611039
# 69234                           0.0              0.0  6075508967039
# 69235                           0.0              0.0  6086020611039
# 69236                           0.0              0.0  6074913432439
# 69237                           0.0              0.0  6075508967039
# 69238                           1.0              0.0  6074913432439
# 69239                           0.0              0.0  6074913432439
# 69240                           1.0              0.0  6074910942439
# 69241                           7.0              0.0  6074910942439
# 69242                           2.0              2.0  6086020611039
# 69243                           0.0              0.0  6086020611039
# 69244                           0.0              0.0  6076580333239
# 69245                           0.0              0.0  6086332786239
# 69246                           0.0              0.0  6076580333239
# 69247                           0.0              0.0  6086332786239
# 69248                           0.0              0.0  6076202446239
# 69249                           0.0              0.0  6086332786239
# 69250                           2.0              2.0  6076202446239
# 69251                           2.0              0.0  6086332786239
# 69252                           1.0              1.0  6076202446239
# 69253                           2.0              1.0  6076202446239
# 69254                           0.0              0.0  6075624367439
# 69255                           0.0              0.0  6086271858039
# 69256                           0.0              0.0  6075624367439
# 69257                           5.0              0.0  6086271858039
# 69258                           1.0              0.0  6075624367439
# 69259                           3.0              0.0  6086271858039
# 69260                           1.0              0.0  6075624367439
# 69261                           4.0              0.0  6086271858039
# 69262                           0.0              0.0  6086333670239
#
#        landing_page_views  session day_of_week  year  month  week_num  \
# 0                     0.0  sheet10        Tues  2019      9        36
# 1                    37.0  sheet10        Tues  2019      9        36
# 2                     4.0  sheet10        Tues  2019      9        36
# 3                     0.0  sheet10        Tues  2019      9        36
# 4                     0.0  sheet10        Tues  2019      9        36
# 5                     5.0  sheet10        Tues  2019      9        36
# 6                     9.0  sheet10        Tues  2019      9        36
# 7                     9.0  sheet10        Tues  2019      9        36
# 8                     0.0  sheet10        Tues  2019      9        36
# 9                     3.0  sheet10        Tues  2019      9        36
# 10                   47.0  sheet10        Tues  2019      9        36
# 11                   43.0  sheet10        Tues  2019      9        36
# 12                    2.0  sheet10        Tues  2019      9        36
# 13                   10.0  sheet10        Tues  2019      9        36
# 14                   36.0  sheet10        Tues  2019      9        36
# 15                  375.0  sheet10        Tues  2019      9        36
# 16                  402.0  sheet10        Tues  2019      9        36
# 17                  248.0  sheet10        Tues  2019      9        36
# 18                   37.0  sheet10        Tues  2019      9        36
# 19                   10.0  sheet10        Tues  2019      9        36
# 20                   10.0  sheet10        Tues  2019      9        36
# 21                    3.0  sheet10        Tues  2019      9        36
# 22                   55.0  sheet10        Tues  2019      9        36
# 23                    5.0  sheet10        Tues  2019      9        36
# 24                    7.0  sheet10        Tues  2019      9        36
# 25                    7.0  sheet10        Tues  2019      9        36
# 26                    5.0  sheet10        Tues  2019      9        36
# 27                   13.0  sheet10        Tues  2019      9        36
# 28                    8.0  sheet10        Tues  2019      9        36
# 29                   70.0  sheet10        Tues  2019      9        36
# ...                   ...      ...         ...   ...    ...       ...
# 69233                20.0   sheet1         Mon  2018      1         1
# 69234                 5.0   sheet1         Mon  2018      1         1
# 69235                 0.0   sheet1         Mon  2018      1         1
# 69236                 1.0   sheet1         Mon  2018      1         1
# 69237                 0.0   sheet1         Mon  2018      1         1
# 69238                28.0   sheet1         Mon  2018      1         1
# 69239                 9.0   sheet1         Mon  2018      1         1
# 69240                 5.0   sheet1         Mon  2018      1         1
# 69241                77.0   sheet1         Mon  2018      1         1
# 69242                20.0   sheet1         Mon  2018      1         1
# 69243                 1.0   sheet1         Mon  2018      1         1
# 69244                 7.0   sheet1         Mon  2018      1         1
# 69245                28.0   sheet1         Mon  2018      1         1
# 69246                 3.0   sheet1         Mon  2018      1         1
# 69247                 4.0   sheet1         Mon  2018      1         1
# 69248                 4.0   sheet1         Mon  2018      1         1
# 69249                29.0   sheet1         Mon  2018      1         1
# 69250                29.0   sheet1         Mon  2018      1         1
# 69251                38.0   sheet1         Mon  2018      1         1
# 69252                22.0   sheet1         Mon  2018      1         1
# 69253                13.0   sheet1         Mon  2018      1         1
# 69254                 9.0   sheet1         Mon  2018      1         1
# 69255                11.0   sheet1         Mon  2018      1         1
# 69256                 2.0   sheet1         Mon  2018      1         1
# 69257               124.0   sheet1         Mon  2018      1         1
# 69258                22.0   sheet1         Mon  2018      1         1
# 69259               146.0   sheet1         Mon  2018      1         1
# 69260                13.0   sheet1         Mon  2018      1         1
# 69261                44.0   sheet1         Mon  2018      1         1
# 69262                 7.0   sheet1         Mon  2018      1         1
#
#       location topic             type                            target  \
# 0         EMEA    ES               PS
# 1         EMEA    UK               PS
# 2         EMEA    UK               PS
# 3         EMEA    UK               PS
# 4         EMEA    UK               PS
# 5         EMEA    UK               PS
# 6         EMEA    UK               PS
# 7         EMEA    UK               PS
# 8         EMEA    UK               PS
# 9         EMEA    UK               PS
# 10        EMEA    UK               PS
# 11        EMEA    UK               PS
# 12        EMEA    UK               PS
# 13        EMEA    UK               PS
# 14          US    PS  LeadSubmissions
# 15          US    PS  LeadSubmissions
# 16          US    PS  LeadSubmissions
# 17          US    PS  LeadSubmissions
# 18          US    PS  LeadSubmissions
# 19        EMEA    ES               PS
# 20        EMEA    UK               PS
# 21        EMEA    UK               PS
# 22        EMEA    IT               PS
# 23          US   RRE  LeadSubmissions
# 24          US   RRE  LeadSubmissions
# 25          US   RRE  LeadSubmissions
# 26          US   RRE  LeadSubmissions
# 27          US   RRE  LeadSubmissions
# 28        EMEA    IT               PS
# 29        EMEA    IT               PS
# ...        ...   ...              ...                               ...
# 69233       US    PS  LeadSubmissions                              ENT
# 69234     EMEA    FR              RRE                          Website
# 69235       US    PS  LeadSubmissions                              ENT
# 69236       DE   RRE  LeadSubmissions          Re-Engagementmax Agents
# 69237     EMEA    FR              RRE                          Website
# 69238       DE   RRE  LeadSubmissions          Re-Engagementmax Agents
# 69239       DE   RRE  LeadSubmissions          Re-Engagementmax Agents
# 69240       MX   RRE     LatinAmerica   Re-Engagementtargeting Website
# 69241       MX   RRE     LatinAmerica   Re-Engagementtargeting Website
# 69242       US    PS  LeadSubmissions                              ENT
# 69243       US    PS  LeadSubmissions                              ENT
# 69244     EMEA    FR               PS
# 69245       DE   RRE  LeadSubmissions                              MQL
# 69246     EMEA    FR               PS
# 69247       DE   RRE  LeadSubmissions                              MQL
# 69248     EMEA    ZA               PS
# 69249       DE   RRE  LeadSubmissions                              MQL
# 69250     EMEA    ZA               PS
# 69251       DE   RRE  LeadSubmissions                              MQL
# 69252     EMEA    ZA               PS
# 69253     EMEA    ZA               PS
# 69254       ZA   RRE  LeadSubmissions      Site Re-Engagementtargeting
# 69255       MX   RRE     LatinAmerica
# 69256       ZA   RRE  LeadSubmissions      Site Re-Engagementtargeting
# 69257       MX   RRE     LatinAmerica
# 69258       ZA   RRE  LeadSubmissions      Site Re-Engagementtargeting
# 69259       MX   RRE     LatinAmerica
# 69260       ZA   RRE  LeadSubmissions      Site Re-Engagementtargeting
# 69261       MX   RRE     LatinAmerica
# 69262     EMEA    FR              RRE
#
#                            target_sub                   version  \
# 0                          Evergreen                        5.1
# 1                          Evergreen                       5.23
# 2                          Evergreen                       5.23
# 3                          Evergreen                       5.23
# 4                          Evergreen                       5.23
# 5                          Evergreen                       5.23
# 6                          Evergreen                       5.23
# 7                          Evergreen                       5.23
# 8                          Evergreen                       5.23
# 9                          Evergreen                       5.23
# 10                         Evergreen                       5.23
# 11                         Evergreen                       5.23
# 12                         Evergreen                       5.23
# 13                         Evergreen                       5.23
# 14      ENT Photography Entrepreneur                       5.22
# 15      ENT Photography Entrepreneur                       5.22
# 16      ENT Photography Entrepreneur                       5.22
# 17      ENT Photography Entrepreneur                       5.22
# 18      ENT Photography Entrepreneur                       5.22
# 19                         Evergreen                        5.1
# 20                         Evergreen                       5.23
# 21                         Evergreen                       5.23
# 22                         All Lists                       5.28
# 23          Page Visitor Remarketing                       oCPM
# 24          Page Visitor Remarketing                       oCPM
# 25          Page Visitor Remarketing                       oCPM
# 26          Page Visitor Remarketing                       oCPM
# 27          Page Visitor Remarketing                       oCPM
# 28                         All Lists                       5.28
# 29                         All Lists                       5.28
# ...                               ...                       ...
# 69233         Self Employed / Drivers   Self Employed / Drivers
# 69234                             LAL                       LAL
# 69235         Self Employed / Drivers   Self Employed / Drivers
# 69236                             LAL                       LAL
# 69237                             LAL                       LAL
# 69238                             LAL                       LAL
# 69239                             LAL                       LAL
# 69240                             LAL                       LAL
# 69241                             LAL                       LAL
# 69242         Self Employed / Drivers   Self Employed / Drivers
# 69243         Self Employed / Drivers   Self Employed / Drivers
# 69244                            SQL                        LAL
# 69245                             LAL                       LAL
# 69246                            SQL                        LAL
# 69247                             LAL                       LAL
# 69248                      MQL & SQL                        LAL
# 69249                             LAL                       LAL
# 69250                      MQL & SQL                        LAL
# 69251                             LAL                       LAL
# 69252                      MQL & SQL                        LAL
# 69253                      MQL & SQL                        LAL
# 69254                             LAL                       LAL
# 69255                   Remax Agents                        LAL
# 69256                             LAL                       LAL
# 69257                   Remax Agents                        LAL
# 69258                             LAL                       LAL
# 69259                   Remax Agents                        LAL
# 69260                             LAL                       LAL
# 69261                   Remax Agents                        LAL
# 69262                            MQL                        LAL
#
#                    target_grouped  conversion                    labels
# 0                       evergreen         0.0   btw 0 and 2 conversions
# 1                       evergreen         1.0   btw 0 and 2 conversions
# 2                       evergreen         0.0   btw 0 and 2 conversions
# 3                       evergreen         0.0   btw 0 and 2 conversions
# 4                       evergreen         0.0   btw 0 and 2 conversions
# 5                       evergreen         1.0   btw 0 and 2 conversions
# 6                       evergreen         0.0   btw 0 and 2 conversions
# 7                       evergreen         1.0   btw 0 and 2 conversions
# 8                       evergreen         0.0   btw 0 and 2 conversions
# 9                       evergreen         0.0   btw 0 and 2 conversions
# 10                      evergreen         4.0   btw 3 and 6 conversions
# 11                      evergreen         2.0   btw 0 and 2 conversions
# 12                      evergreen         0.0   btw 0 and 2 conversions
# 13                      evergreen         0.0   btw 0 and 2 conversions
# 14     entphotographyentrepreneur         3.0   btw 3 and 6 conversions
# 15     entphotographyentrepreneur        20.0  more than 12 conversions
# 16     entphotographyentrepreneur        18.0  more than 12 conversions
# 17     entphotographyentrepreneur         6.0   btw 3 and 6 conversions
# 18     entphotographyentrepreneur         5.0   btw 3 and 6 conversions
# 19                      evergreen         1.0   btw 0 and 2 conversions
# 20                      evergreen         2.0   btw 0 and 2 conversions
# 21                      evergreen         1.0   btw 0 and 2 conversions
# 22                       alllists         1.0   btw 0 and 2 conversions
# 23         pagevisitorremarketing         0.0   btw 0 and 2 conversions
# 24         pagevisitorremarketing         0.0   btw 0 and 2 conversions
# 25         pagevisitorremarketing         1.0   btw 0 and 2 conversions
# 26         pagevisitorremarketing         0.0   btw 0 and 2 conversions
# 27         pagevisitorremarketing         1.0   btw 0 and 2 conversions
# 28                       alllists         0.0   btw 0 and 2 conversions
# 29                       alllists         0.0   btw 0 and 2 conversions
# ...                           ...         ...                       ...
# 69233      entselfemployeddrivers         1.0   btw 0 and 2 conversions
# 69234                  websitelal         0.0   btw 0 and 2 conversions
# 69235      entselfemployeddrivers         0.0   btw 0 and 2 conversions
# 69236              remaxagentslal         0.0   btw 0 and 2 conversions
# 69237                  websitelal         0.0   btw 0 and 2 conversions
# 69238              remaxagentslal         1.0   btw 0 and 2 conversions
# 69239              remaxagentslal         0.0   btw 0 and 2 conversions
# 69240       retargetingwebsitelal         1.0   btw 0 and 2 conversions
# 69241       retargetingwebsitelal         7.0  btw 7 and 12 conversions
# 69242      entselfemployeddrivers         2.0   btw 0 and 2 conversions
# 69243      entselfemployeddrivers         0.0   btw 0 and 2 conversions
# 69244                         sql         0.0   btw 0 and 2 conversions
# 69245                      mqllal         0.0   btw 0 and 2 conversions
# 69246                         sql         0.0   btw 0 and 2 conversions
# 69247                      mqllal         0.0   btw 0 and 2 conversions
# 69248                      mqlsql         0.0   btw 0 and 2 conversions
# 69249                      mqllal         0.0   btw 0 and 2 conversions
# 69250                      mqlsql         2.0   btw 0 and 2 conversions
# 69251                      mqllal         2.0   btw 0 and 2 conversions
# 69252                      mqlsql         1.0   btw 0 and 2 conversions
# 69253                      mqlsql         2.0   btw 0 and 2 conversions
# 69254          siteretargetinglal         0.0   btw 0 and 2 conversions
# 69255                 remaxagents         0.0   btw 0 and 2 conversions
# 69256          siteretargetinglal         0.0   btw 0 and 2 conversions
# 69257                 remaxagents         5.0   btw 3 and 6 conversions
# 69258          siteretargetinglal         1.0   btw 0 and 2 conversions
# 69259                 remaxagents         3.0   btw 3 and 6 conversions
# 69260          siteretargetinglal         1.0   btw 0 and 2 conversions
# 69261                 remaxagents         4.0   btw 3 and 6 conversions
# 69262                         mql         0.0   btw 0 and 2 conversions
#
# [69263 rows x 43 columns]

# %%
fb_ls.location.value_counts()
# Out:
# EMEA    31038
# US      23519
# MX       4434
# DE       3130
# UK       2145
# CA       2095
# AU       1703
# ZA       1134
# SE         65
# Name: location, dtype: int64

# %%
fb_ls.topic.value_counts()
# Out:
# RRE    30777
# PS     12769
# FR      7304
# UK      6177
# ES      5397
# ZA      2345
# IT      2287
# DE      1243
# PL       964
# Name: topic, dtype: int64

# %%
fb_ls.type.value_counts()
# Out:
# LeadSubmissions    38730
# PS                 12892
# RRE                12825
# LatinAmerica        4230
# P1Areas              297
# LATAM                204
# Device                85
# Name: type, dtype: int64

# %%
fb_ls[(fb_ls['location'] == 'EMEA') & ((fb_ls['topic'] == 'PS')|(fb_ls['topic'] == 'RRE'))]['type'].value_counts()
# Out:
# LeadSubmissions    5321
# Name: type, dtype: int64

# %%
fb_emea = fb_ls[fb_ls['location'] == 'EMEA'][['location','topic','type','target_sub']]
fb_emea[(fb_emea['topic'] == "PS") | (fb_emea['topic'] == "RRE")]['type'].value_counts()
# fb_emea
# Out:
# LeadSubmissions    5321
# Name: type, dtype: int64

# %%
loc_lst = []

for i in range(len(fb_ls)):
    if fb_ls['location'][i] == 'EMEA':
        if (fb_ls['topic'][i] == 'PS') | (fb_ls['topic'][i] == 'RRE'):
            loc_lst.append('EMEA')
        else:
            loc_lst.append(fb_ls['topic'][i])
    else:
        loc_lst.append(fb_ls['location'][i])
        
pd.Series(loc_lst).value_counts()
# Out:
# US      23519
# UK       8322
# FR       7304
# ES       5397
# EMEA     5321
# MX       4434
# DE       4373
# ZA       3479
# IT       2287
# CA       2095
# AU       1703
# PL        964
# SE         65
# dtype: int64

# %%
print(pd.Series(loc_lst).value_counts().sum())
print(len(fb_ls))
# Out:
# 69263
# 69263

# %%
fb_ls['location1'] = loc_lst
fb_ls.location1.value_counts()
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# US      23519
# UK       8322
# FR       7304
# ES       5397
# EMEA     5321
# MX       4434
# DE       4373
# ZA       3479
# IT       2287
# CA       2095
# AU       1703
# PL        964
# SE         65
# Name: location1, dtype: int64

# %%
fb_ls[fb_ls['location'] == 'EMEA']['topic'].value_counts()
# Out:
# FR     7304
# UK     6177
# ES     5397
# RRE    3196
# ZA     2345
# IT     2287
# PS     2125
# DE     1243
# PL      964
# Name: topic, dtype: int64

# %%
fb_ls[(fb_ls['location'] == 'EMEA') & ((fb_ls['topic'] != 'PS')&(fb_ls['topic'] != 'RRE')) &
      (fb_ls['type'] == 'LeadSubmissions')]['ad_set_name'].value_counts()
# Out:
# Series([], Name: ad_set_name, dtype: int64)

# %%
fb_ls[(fb_ls['location'] == 'EMEA') & ((fb_ls['topic'] != 'PS')&(fb_ls['topic'] != 'RRE'))]['type'].value_counts()
# Out:
# PS     12892
# RRE    12825
# Name: type, dtype: int64

# %%
topic_lst = []

for i in range(len(fb_ls)):
    if fb_ls['location'][i] == 'EMEA':
        if (fb_ls['topic'][i] != 'PS') & (fb_ls['topic'][i] != 'RRE'):
            topic_lst.append(fb_ls['type'][i])
        else:
            topic_lst.append(fb_ls['topic'][i])
    else:
        topic_lst.append(fb_ls['topic'][i])
        
pd.Series(topic_lst).value_counts()
# Out:
# RRE    43602
# PS     25661
# dtype: int64

# %%
print(pd.Series(topic_lst).value_counts().sum())
print(len(fb_ls))
# Out:
# 69263
# 69263

# %%
fb_ls['topic1'] = topic_lst
fb_ls.topic1.value_counts()
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# RRE    43602
# PS     25661
# Name: topic1, dtype: int64

# %%
fb_ls.drop(columns = ['location','topic'], inplace=True)
fb_ls = fb_ls.rename(columns={'location1':'location',
                      'topic1':'topic'})
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# Saving the file to S3:
from io import StringIO
import boto3

bucket='facebookconversionrates' # bucket name
data_key = 'preprocessing/fb_prepro.csv' # name of the csv file that will be created
csv_buffer = StringIO()
fb_ls.to_csv(csv_buffer)
s3_resource = boto3.resource('s3')
s3_resource.Object(bucket, data_key).put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': '82B9413703E15F7A',
#   'HostId': '4J2Cku4e9xuCgrILUxOIUtq9ftcEBTULodF1756VdvEl3ZcFraXin08KI33VliNWFmmw1DSgl+Y=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '4J2Cku4e9xuCgrILUxOIUtq9ftcEBTULodF1756VdvEl3ZcFraXin08KI33VliNWFmmw1DSgl+Y=',
#    'x-amz-request-id': '82B9413703E15F7A',
#    'date': 'Thu, 05 Sep 2019 18:27:19 GMT',
#    'etag': '"420d3eb98f16d67bf422cbee58a8f9d4"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"420d3eb98f16d67bf422cbee58a8f9d4"'}

# %% [markdown]
# ## Generating the Final CSV File

# %% [markdown]
# In this section, I will create a CSV file containing all the combinations of age, location, topic, date and target groups.

# %%
# Create a list that gives all the dates between the initial and the last date.
d1 = date1  # start date
d2 = date2  # end date

delta = d2 - d1  # timedelta

dates = [] # empty list to store all the dates in between

for i in range(delta.days + 1):
    dates.append(d1 + timedelta(days=i))

dates
# Out:
# [datetime.date(2019, 8, 1),
#  datetime.date(2019, 8, 2),
#  datetime.date(2019, 8, 3),
#  datetime.date(2019, 8, 4),
#  datetime.date(2019, 8, 5),
#  datetime.date(2019, 8, 6),
#  datetime.date(2019, 8, 7),
#  datetime.date(2019, 8, 8),
#  datetime.date(2019, 8, 9),
#  datetime.date(2019, 8, 10),
#  datetime.date(2019, 8, 11),
#  datetime.date(2019, 8, 12),
#  datetime.date(2019, 8, 13),
#  datetime.date(2019, 8, 14),
#  datetime.date(2019, 8, 15),
#  datetime.date(2019, 8, 16),
#  datetime.date(2019, 8, 17),
#  datetime.date(2019, 8, 18),
#  datetime.date(2019, 8, 19),
#  datetime.date(2019, 8, 20),
#  datetime.date(2019, 8, 21),
#  datetime.date(2019, 8, 22),
#  datetime.date(2019, 8, 23),
#  datetime.date(2019, 8, 24),
#  datetime.date(2019, 8, 25),
#  datetime.date(2019, 8, 26),
#  datetime.date(2019, 8, 27),
#  datetime.date(2019, 8, 28),
#  datetime.date(2019, 8, 29),
#  datetime.date(2019, 8, 30),
#  datetime.date(2019, 8, 31)]

# %%
fb_ls['location'].value_counts()
# Out:
# US      23519
# UK       8322
# FR       7304
# ES       5397
# EMEA     5321
# MX       4434
# DE       4373
# ZA       3479
# IT       2287
# CA       2095
# AU       1703
# PL        964
# SE         65
# Name: location, dtype: int64

# %%
# Percentage of all EMEA values in the dataframe. 
# In other words, the observations that don't have exact location.
len(fb_ls[fb_ls['location'] == 'EMEA'])/fb_ls['location'].value_counts().sum()
# Out:
# 0.07682312345696837

# %%
age=['18-24', '25-34', '35-44', '45-54', '55-64', '65+'] # all combinations for age
locations = ['US','UK','FR', 'ES', 'ZA','IT','AU','DE','MX','CA'] # all combinations for location
topics = ['RRE','PS'] # all combinations for topic

# %%
fb_ls.columns
# Out:
# Index(['ad_account_id', 'ad_account_name', 'reporting_starts',
#        'reporting_ends', 'ad_set_name', 'age', 'ad_set_delivery', 'bid',
#        'bid_type', 'ad_set_budget', 'ad_set_budget_type',
#        'last_significant_edit', 'results', 'result_indicator', 'reach',
#        'impressions', 'cost_per_results', 'amount_spent_(usd)', 'ends',
#        'starts', 'link_clicks', 'website_purchases', 'leads_(form)',
#        'campaign_name', 'campaign_id', 'lead_page_contains_thank-you',
#        'lead_submission', 'ad_set_id', 'landing_page_views', 'session',
#        'day_of_week', 'year', 'month', 'week_num', 'type', 'target',
#        'target_sub', 'version', 'target_grouped', 'conversion', 'labels',
#        'location', 'topic'],
#       dtype='object')

# %% [markdown]
# A mask is created to get the PS or RRE types:

# %%
mask1 = fb_ls['topic'].str.contains("PS")
mask2 = fb_ls['topic'].str.contains("RRE")
mask3 = fb_ls['type'].str.contains("PS")
mask4 = fb_ls['type'].str.contains("RRE")

# %%
PS_groups = fb_ls[mask1 | mask3].target_grouped.value_counts().index.tolist()

# %%
RRE_groups = fb_ls[mask2 | mask4].target_grouped.value_counts().index.tolist()

# %% [markdown]
# As a result two different lists are generated. They included all the target groups recorded for the corresponding topic.

# %%
fb_ls[mask1 | mask3].target_grouped.value_counts()[:10] # PS_groups with the frequency of each targeted group
# Out:
# evergreen                 6571
# entselfemployeddrivers    2893
# alllists                  2468
# mql                       1885
# febpromo                  1368
# websiteremarketing        1248
# mqlsql                    1179
# openedleadformlal         1146
# videoremarketinglal        921
# sql                        755
# Name: target_grouped, dtype: int64

# %%
fb_ls[mask2 | mask4].target_grouped.value_counts()[:10] # RRE_groups with the frequency of each targeted group
# Out:
# alllists                 7942
# websiteremarketing       2881
# remaxagents              2606
# evergreen                2428
# retargetingwebsitelal    1936
# agentsbrokers            1624
# febpromo                 1560
# mqllal                   1452
# remaxagentsbrokerslal    1169
# engl                     1016
# Name: target_grouped, dtype: int64

# %% [markdown]
# According to the analysis on [Data Studio](https://datastudio.google.com/u/0/reporting/1GT-CBxp6O-_IW5b55d6NTLFTa1fTJud0/page/eKxs), three most targeted groups are picked in the June '19 and early July '19.

# %%
PS_groups_upd = ['evergreen','entphotographyentrepreneur','infographic', 'photographers']

# %%
RRE_groups_upd = ['evergreen','pagevisitorremarketing']

# %% [markdown]
# ### Assumption:
# Here there is an assumption to underline:
# The most recently used target groups are picked as the targeted groups. The most recent two months are taken into consideration and the most commonly targeted 3 groups are picked for both PS and RRE.

# %%
target_grouped = PS_groups_upd + RRE_groups_upd

# %%
target_grouped
# Out:
# ['evergreen',
#  'entphotographyentrepreneur',
#  'infographic',
#  'photographers',
#  'evergreen',
#  'pagevisitorremarketing']

# %%
# Creating the first version of the dataframe:
df_testset = pd.DataFrame(list(product(dates,age,locations,topics,target_grouped)), 
                          columns = ['date','age','location','topic','target_grouped1'])

# %%
# The date column is divided into year, month and week number.
df_testset['date'] = pd.to_datetime(df_testset['date'], errors = 'coerce')

df_testset['year'] = df_testset['date'].dt.year
df_testset['month'] = df_testset['date'].dt.month
df_testset['week_num'] = df_testset['date'].dt.week

df_testset['day_of_week']=df_testset['date'].dt.dayofweek
days = {0:'Mon',1:'Tues',2:'Weds',3:'Thurs',4:'Fri',5:'Sat',6:'Sun'}
df_testset['day_of_week'] = df_testset['day_of_week'].apply(lambda x: days[x])

# %%
# While creating the combinations, target_grouped1 column is used to add the target groups of each topic. 
# But the point to pay attention is we cannot create all the combinations of this column just like a seperate column.
# The reason is some belongs to PS and some to RRE. So we need to delete all unmatching topic and target groups. 
# Below for loop assigns np.nan to PS target group column if they are not in the initial list of PS target groups and the 
# same process for RRE. Then the rows containing empty values are dropped.

# df_testset['target_grouped'] = np.nan
some_lst = []

for i in range(len(df_testset)):
    if df_testset['topic'][i] == 'RRE':
        if df_testset['target_grouped1'][i] not in RRE_groups_upd:
#             df_testset['target_grouped'][i] = np.nan
            some_lst.append('')
        else:
#             df_testset['target_grouped'][i] = df_testset['target_grouped1'][i]
            some_lst.append(df_testset['target_grouped1'][i])
    elif df_testset['topic'][i] == 'PS':
        if df_testset['target_grouped1'][i] not in PS_groups_upd:
#             df_testset['target_grouped'][i] = np.nan
            some_lst.append('')
        else:
#             df_testset['target_grouped'][i] = df_testset['target_grouped1'][i]
            some_lst.append(df_testset['target_grouped1'][i])
    else:
        print("Value other than PS and RRE detected!")
        break
        
df_testset['target_grouped'] = pd.Series(some_lst)
df_testset['target_grouped'] = df_testset['target_grouped'].replace('',np.nan)
df_testset.dropna(inplace = True)
df_testset.drop(columns = ['target_grouped1'], inplace = True)

# %%
# Dropping the duplicates and resetting the index of the dataframe:
df_testset = df_testset.drop_duplicates().reset_index(drop = True)

# %%
# Just to verify that we deleted all unmatching topic and target group pairings.
df_testset['target_grouped'].value_counts()
# Out:
# evergreen                     3720
# entphotographyentrepreneur    1860
# infographic                   1860
# photographers                 1860
# pagevisitorremarketing        1860
# Name: target_grouped, dtype: int64

# %%
# Column rearrangement:
df_testset = df_testset[['date','year','month','week_num','day_of_week','age','location','topic','target_grouped']]

# %%
df_testset
# Out:
#             date  year  month  week_num day_of_week    age location topic  \
# 0     2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 1     2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 2     2019-08-01  2019      8        31       Thurs  18-24       US    PS
# 3     2019-08-01  2019      8        31       Thurs  18-24       US    PS
# 4     2019-08-01  2019      8        31       Thurs  18-24       US    PS
# 5     2019-08-01  2019      8        31       Thurs  18-24       US    PS
# 6     2019-08-01  2019      8        31       Thurs  18-24       UK   RRE
# 7     2019-08-01  2019      8        31       Thurs  18-24       UK   RRE
# 8     2019-08-01  2019      8        31       Thurs  18-24       UK    PS
# 9     2019-08-01  2019      8        31       Thurs  18-24       UK    PS
# 10    2019-08-01  2019      8        31       Thurs  18-24       UK    PS
# 11    2019-08-01  2019      8        31       Thurs  18-24       UK    PS
# 12    2019-08-01  2019      8        31       Thurs  18-24       FR   RRE
# 13    2019-08-01  2019      8        31       Thurs  18-24       FR   RRE
# 14    2019-08-01  2019      8        31       Thurs  18-24       FR    PS
# 15    2019-08-01  2019      8        31       Thurs  18-24       FR    PS
# 16    2019-08-01  2019      8        31       Thurs  18-24       FR    PS
# 17    2019-08-01  2019      8        31       Thurs  18-24       FR    PS
# 18    2019-08-01  2019      8        31       Thurs  18-24       ES   RRE
# 19    2019-08-01  2019      8        31       Thurs  18-24       ES   RRE
# 20    2019-08-01  2019      8        31       Thurs  18-24       ES    PS
# 21    2019-08-01  2019      8        31       Thurs  18-24       ES    PS
# 22    2019-08-01  2019      8        31       Thurs  18-24       ES    PS
# 23    2019-08-01  2019      8        31       Thurs  18-24       ES    PS
# 24    2019-08-01  2019      8        31       Thurs  18-24       ZA   RRE
# 25    2019-08-01  2019      8        31       Thurs  18-24       ZA   RRE
# 26    2019-08-01  2019      8        31       Thurs  18-24       ZA    PS
# 27    2019-08-01  2019      8        31       Thurs  18-24       ZA    PS
# 28    2019-08-01  2019      8        31       Thurs  18-24       ZA    PS
# 29    2019-08-01  2019      8        31       Thurs  18-24       ZA    PS
# ...          ...   ...    ...       ...         ...    ...      ...   ...
# 11130 2019-08-31  2019      8        35         Sat    65+       IT   RRE
# 11131 2019-08-31  2019      8        35         Sat    65+       IT   RRE
# 11132 2019-08-31  2019      8        35         Sat    65+       IT    PS
# 11133 2019-08-31  2019      8        35         Sat    65+       IT    PS
# 11134 2019-08-31  2019      8        35         Sat    65+       IT    PS
# 11135 2019-08-31  2019      8        35         Sat    65+       IT    PS
# 11136 2019-08-31  2019      8        35         Sat    65+       AU   RRE
# 11137 2019-08-31  2019      8        35         Sat    65+       AU   RRE
# 11138 2019-08-31  2019      8        35         Sat    65+       AU    PS
# 11139 2019-08-31  2019      8        35         Sat    65+       AU    PS
# 11140 2019-08-31  2019      8        35         Sat    65+       AU    PS
# 11141 2019-08-31  2019      8        35         Sat    65+       AU    PS
# 11142 2019-08-31  2019      8        35         Sat    65+       DE   RRE
# 11143 2019-08-31  2019      8        35         Sat    65+       DE   RRE
# 11144 2019-08-31  2019      8        35         Sat    65+       DE    PS
# 11145 2019-08-31  2019      8        35         Sat    65+       DE    PS
# 11146 2019-08-31  2019      8        35         Sat    65+       DE    PS
# 11147 2019-08-31  2019      8        35         Sat    65+       DE    PS
# 11148 2019-08-31  2019      8        35         Sat    65+       MX   RRE
# 11149 2019-08-31  2019      8        35         Sat    65+       MX   RRE
# 11150 2019-08-31  2019      8        35         Sat    65+       MX    PS
# 11151 2019-08-31  2019      8        35         Sat    65+       MX    PS
# 11152 2019-08-31  2019      8        35         Sat    65+       MX    PS
# 11153 2019-08-31  2019      8        35         Sat    65+       MX    PS
# 11154 2019-08-31  2019      8        35         Sat    65+       CA   RRE
# 11155 2019-08-31  2019      8        35         Sat    65+       CA   RRE
# 11156 2019-08-31  2019      8        35         Sat    65+       CA    PS
# 11157 2019-08-31  2019      8        35         Sat    65+       CA    PS
# 11158 2019-08-31  2019      8        35         Sat    65+       CA    PS
# 11159 2019-08-31  2019      8        35         Sat    65+       CA    PS
#
#                    target_grouped
# 0                       evergreen
# 1          pagevisitorremarketing
# 2                       evergreen
# 3      entphotographyentrepreneur
# 4                     infographic
# 5                   photographers
# 6                       evergreen
# 7          pagevisitorremarketing
# 8                       evergreen
# 9      entphotographyentrepreneur
# 10                    infographic
# 11                  photographers
# 12                      evergreen
# 13         pagevisitorremarketing
# 14                      evergreen
# 15     entphotographyentrepreneur
# 16                    infographic
# 17                  photographers
# 18                      evergreen
# 19         pagevisitorremarketing
# 20                      evergreen
# 21     entphotographyentrepreneur
# 22                    infographic
# 23                  photographers
# 24                      evergreen
# 25         pagevisitorremarketing
# 26                      evergreen
# 27     entphotographyentrepreneur
# 28                    infographic
# 29                  photographers
# ...                           ...
# 11130                   evergreen
# 11131      pagevisitorremarketing
# 11132                   evergreen
# 11133  entphotographyentrepreneur
# 11134                 infographic
# 11135               photographers
# 11136                   evergreen
# 11137      pagevisitorremarketing
# 11138                   evergreen
# 11139  entphotographyentrepreneur
# 11140                 infographic
# 11141               photographers
# 11142                   evergreen
# 11143      pagevisitorremarketing
# 11144                   evergreen
# 11145  entphotographyentrepreneur
# 11146                 infographic
# 11147               photographers
# 11148                   evergreen
# 11149      pagevisitorremarketing
# 11150                   evergreen
# 11151  entphotographyentrepreneur
# 11152                 infographic
# 11153               photographers
# 11154                   evergreen
# 11155      pagevisitorremarketing
# 11156                   evergreen
# 11157  entphotographyentrepreneur
# 11158                 infographic
# 11159               photographers
#
# [11160 rows x 9 columns]

# %% [markdown]
# To verify that all the combinations are created, the length of the dataframe is calculated which turned out to be 1512. It is important to calculate the same number by multiplying the possibilities of each column. So let's multiply the amount of different:
# - dates
# - age groups
# - locations
# - topics
# - target_grouped
# $$ 5*6*6*6 = 1080 $$
#
# This is the proof that each possible combination is created!

# %%
len(df_testset)
# Out:
# 11160

# %%
31*6*10*6
# Out:
# 11160

# %% [markdown]
# ## Adding the incremental increase:

# %% [markdown]
# ### Warning:
# By creating the amount spent column, I created from 10 to 250 with increments of 10. But since we have so many combinations, the amount of 250 dollars might not be reached. If we assign a daily budget of 4000 dollars, we are left with 13 dollars per combination on average.
# The upper limit of 250 dollars might need adjustment in the later stages.

# %%
# Since there are 60 increments, we need to concatenate the already existing dataframe 24 times with itself.
df_increment = pd.concat([df_testset]*len(pd.Series(range(50,3001,10)))).reset_index(drop=True)

# %%
pd.Series(range(50,3001,10))
# Out:
# 0        50
# 1        60
# 2        70
# 3        80
# 4        90
# 5       100
# 6       110
# 7       120
# 8       130
# 9       140
# 10      150
# 11      160
# 12      170
# 13      180
# 14      190
# 15      200
# 16      210
# 17      220
# 18      230
# 19      240
# 20      250
# 21      260
# 22      270
# 23      280
# 24      290
# 25      300
# 26      310
# 27      320
# 28      330
# 29      340
#        ...
# 266    2710
# 267    2720
# 268    2730
# 269    2740
# 270    2750
# 271    2760
# 272    2770
# 273    2780
# 274    2790
# 275    2800
# 276    2810
# 277    2820
# 278    2830
# 279    2840
# 280    2850
# 281    2860
# 282    2870
# 283    2880
# 284    2890
# 285    2900
# 286    2910
# 287    2920
# 288    2930
# 289    2940
# 290    2950
# 291    2960
# 292    2970
# 293    2980
# 294    2990
# 295    3000
# Length: 296, dtype: int64

# %%
inc = list(range(50,3001,10))

# %%
some_lst = []
for i in range(len(inc)):
    some_lst = some_lst + ([inc[i]]*len(df_testset))

# %% [markdown]
# Checking the length of :
# - new dataframe
# - 60 times the old one
# - the list, which we will paste on the 'amount_spent_(usd)' column
#
# They all need to give the same number and they do:

# %%
len(df_increment)
# Out:
# 3303360

# %%
len(df_testset)*len(range(50,3001,10))
# Out:
# 3303360

# %%
len(some_lst)
# Out:
# 3303360

# %%
df_increment['amount_spend_usd'] = pd.Series(some_lst)

# %%
df_increment.reset_index(drop=True, inplace=True)

# %%
# Checking a certain combination and seeing whether the incremental increase in 'amount_spent_(usd)' works:
df_increment[(df_increment['day_of_week'] == 'Thurs') & (df_increment['location'] == 'US') & 
             (df_increment['topic'] == 'RRE') & (df_increment['target_grouped'] == 'evergreen') &
             (df_increment['age'] == '18-24') ]
# Out:
#               date  year  month  week_num day_of_week    age location topic  \
# 0       2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 2520    2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 5040    2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 7560    2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 10080   2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 11160   2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 13680   2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 16200   2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 18720   2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 21240   2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 22320   2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 24840   2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 27360   2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 29880   2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 32400   2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 33480   2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 36000   2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 38520   2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 41040   2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 43560   2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 44640   2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 47160   2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 49680   2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 52200   2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 54720   2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 55800   2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 58320   2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 60840   2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 63360   2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 65880   2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# ...            ...   ...    ...       ...         ...    ...      ...   ...
# 3236400 2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 3238920 2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 3241440 2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 3243960 2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 3246480 2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 3247560 2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 3250080 2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 3252600 2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 3255120 2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 3257640 2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 3258720 2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 3261240 2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 3263760 2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 3266280 2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 3268800 2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 3269880 2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 3272400 2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 3274920 2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 3277440 2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 3279960 2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 3281040 2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 3283560 2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 3286080 2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 3288600 2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 3291120 2019-08-29  2019      8        35       Thurs  18-24       US   RRE
# 3292200 2019-08-01  2019      8        31       Thurs  18-24       US   RRE
# 3294720 2019-08-08  2019      8        32       Thurs  18-24       US   RRE
# 3297240 2019-08-15  2019      8        33       Thurs  18-24       US   RRE
# 3299760 2019-08-22  2019      8        34       Thurs  18-24       US   RRE
# 3302280 2019-08-29  2019      8        35       Thurs  18-24       US   RRE
#
#         target_grouped  amount_spend_usd
# 0            evergreen                50
# 2520         evergreen                50
# 5040         evergreen                50
# 7560         evergreen                50
# 10080        evergreen                50
# 11160        evergreen                60
# 13680        evergreen                60
# 16200        evergreen                60
# 18720        evergreen                60
# 21240        evergreen                60
# 22320        evergreen                70
# 24840        evergreen                70
# 27360        evergreen                70
# 29880        evergreen                70
# 32400        evergreen                70
# 33480        evergreen                80
# 36000        evergreen                80
# 38520        evergreen                80
# 41040        evergreen                80
# 43560        evergreen                80
# 44640        evergreen                90
# 47160        evergreen                90
# 49680        evergreen                90
# 52200        evergreen                90
# 54720        evergreen                90
# 55800        evergreen               100
# 58320        evergreen               100
# 60840        evergreen               100
# 63360        evergreen               100
# 65880        evergreen               100
# ...                ...               ...
# 3236400      evergreen              2950
# 3238920      evergreen              2950
# 3241440      evergreen              2950
# 3243960      evergreen              2950
# 3246480      evergreen              2950
# 3247560      evergreen              2960
# 3250080      evergreen              2960
# 3252600      evergreen              2960
# 3255120      evergreen              2960
# 3257640      evergreen              2960
# 3258720      evergreen              2970
# 3261240      evergreen              2970
# 3263760      evergreen              2970
# 3266280      evergreen              2970
# 3268800      evergreen              2970
# 3269880      evergreen              2980
# 3272400      evergreen              2980
# 3274920      evergreen              2980
# 3277440      evergreen              2980
# 3279960      evergreen              2980
# 3281040      evergreen              2990
# 3283560      evergreen              2990
# 3286080      evergreen              2990
# 3288600      evergreen              2990
# 3291120      evergreen              2990
# 3292200      evergreen              3000
# 3294720      evergreen              3000
# 3297240      evergreen              3000
# 3299760      evergreen              3000
# 3302280      evergreen              3000
#
# [1480 rows x 10 columns]

# %%
df_increment.to_csv('/home/ec2-user/SageMaker/fb_generating_test_data_2019-07-09/testdata_aug.csv')

# %%
# Saving the file to S3:
from io import StringIO
import boto3

bucket='facebookconversionrates' # bucket name
data_key = 'test_data/testdata_aug.csv' # name of the csv file that will be created
csv_buffer = StringIO()
df_increment.to_csv(csv_buffer)
s3_resource = boto3.resource('s3')
s3_resource.Object(bucket, data_key).put(Body=csv_buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': 'A6835C6B7ED730B0',
#   'HostId': 'kN74GWi21tXz7Hgwj/o1+44hN8qMGh874+fpLnNz+PA+S8W/fmCLtthP8tf6IMZpBKY0n5L2qpQ=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'kN74GWi21tXz7Hgwj/o1+44hN8qMGh874+fpLnNz+PA+S8W/fmCLtthP8tf6IMZpBKY0n5L2qpQ=',
#    'x-amz-request-id': 'A6835C6B7ED730B0',
#    'date': 'Fri, 06 Sep 2019 14:45:07 GMT',
#    'etag': '"9df4fd9ec0c6e263457d3471e7b78946"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"9df4fd9ec0c6e263457d3471e7b78946"'}
